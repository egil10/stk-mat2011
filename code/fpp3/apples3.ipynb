# %% [markdown]
# # APPLES 3

# %% [markdown]
# ### IMPORT

# %%
import os, sys, warnings
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from arch import arch_model 

warnings.filterwarnings("ignore")
sys.path.append(os.path.abspath('../scripts'))

from spread import SPREAD
from engine import ENGINE
from backtester import BACKTESTER
from tearsheet import TEARSHEET
from screener import SCREENER

# %% [markdown]
# ### DATA

# %%
months = [
    "202501", "202502", "202503", "202504", "202505", "202506",
    "202507", "202508", "202509", "202510", "202511", "202512"
]

my_files = [
    [f"../data/processed/audusd_dukascopy_ask_{m}.parquet" for m in months],
    [f"../data/processed/audusd_dukascopy_bid_{m}.parquet" for m in months],
    [f"../data/processed/nzdusd_dukascopy_ask_{m}.parquet" for m in months],
    [f"../data/processed/nzdusd_dukascopy_bid_{m}.parquet" for m in months]
]

# %% [markdown]
# ### SPREAD

# %%
builder = SPREAD(threshold=1000) 
df = builder.build(my_files)

print(df.head(5))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20100\3440201596.py in ?()
#       1 builder = SPREAD(threshold=1000)
# ----> 2 df = builder.build(my_files)
#       3
#       4 print(df.head(5))
#
# c:\Users\ofurn\Dokumenter\Github\stk-mat2011\code\scripts\spread.py in ?(self, file_paths)
#      87         if len(file_paths) != 4:
#      88             raise ValueError("Provide exactly 4 file paths: [ask_a, bid_a, ask_b, bid_b]")
#      89
#      90         # build bars for both assets
# ---> 91         bars_a = self._aggregate_bars(file_paths[0], file_paths[1])
#      92         bars_b = self._aggregate_bars(file_paths[2], file_paths[3])
#      93
#      94         # asynchronous merge to align bars without look-ahead bias
#
# c:\Users\ofurn\Dokumenter\Github\stk-mat2011\code\scripts\spread.py in ?(self, ask_file, bid_file)
#      41         into volume bars for a single asset
#      42         """
#      43
#      44         # load and rename
# ---> 45         df_ask = self._load_parquet(ask_file).sort_values('datetime').rename(columns={'price': 'ask_price', 'volume': 'ask_volume'})
#      46         df_bid = self._load_parquet(bid_file).sort_values('datetime').rename(columns={'price': 'bid_price', 'volume': 'bid_volume'})
#      47
#      48         # clipping active trading hours
#
# c:\Users\ofurn\Dokumenter\Github\stk-mat2011\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7207             )
#    7208         elif len(by):
#    7209             # len(by) == 1
#    7210
# -> 7211             k = self._get_label_or_level_values(by[0], axis=axis)
#    7212
#    7213             # need to rewrap column in Series to apply key function
#    7214             if key is not None:
#
# c:\Users\ofurn\Dokumenter\Github\stk-mat2011\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1904         """
#    1905         axis = self._get_axis_number(axis)
#    1906         other_axes = [ax for ax in range(self._AXIS_LEN) if ax != axis]
#    1907
# -> 1908         if self._is_label_reference(key, axis=axis):
#    1909             self._check_label_or_level_ambiguity(key, axis=axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#
# c:\Users\ofurn\Dokumenter\Github\stk-mat2011\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1797
#    1798         return (
#    1799             key is not None
#    1800             and is_hashable(key)
# -> 1801             and any(key in self.axes[ax] for ax in other_axes)
#    1802         )
#
# c:\Users\ofurn\Dokumenter\Github\stk-mat2011\.venv\Lib\site-packages\pandas\core\generic.py in ?(.0)
# -> 1801     def _is_label_reference(self, key: Level, axis: Axis = 0) -> bool_t:
#    1802         """
#    1803         Test whether a key is a label reference for a given axis.
#    1804
#
# c:\Users\ofurn\Dokumenter\Github\stk-mat2011\.venv\Lib\site-packages\pandas\core\generic.py in ?(.0)
# -> 1796     def _is_label_reference(self, key: Level, axis: Axis = 0) -> bool_t:
#    1797         """
#    1798         Test whether a key is a label reference for a given axis.
#    1799
#
# KeyboardInterrupt:

# %% [markdown]
# ### SCREENER

# %%
screener = SCREENER(df['Asset_A'], df['Asset_B'])
p_val, hl = screener.generate_report()
# Out:
# ========================================
#      COINTEGRATION SCREENER REPORT
# ========================================
# P-Value:    0.98265 -> fail (not cointegrated)
# Half-Life:  1248.68 Bars
# ----------------------------------------
# Verdict: DO NOT TRADE. Spread is a random walk.
# ========================================

# %% [markdown]
# ### ENGINE

# %%
df['Date'] = df.index.date
unique_days = df['Date'].unique()

train_days = 30 
print_freq = 10  # Set how often you want a daily update
out_of_sample_results = []
parameter_tracker = [] 

# The Walk-Forward Loop
for i in range(train_days, len(unique_days)):
    train_dates = unique_days[i - train_days : i]
    test_date = unique_days[i]
    
    train_df = df[df['Date'].isin(train_dates)].copy()
    test_df = df[df['Date'] == test_date].copy()
    
    # Fit Models
    engine = ENGINE(train_df)
    train_fitted = engine.fit_cointegration(z_window=250)
    engine.fit_ar_reversion(lags=1)
    engine.fit_garch_vol(scaling=10000)
    engine.fit_markov_regimes(k_regimes=2)
    
    # Predict Out-of-Sample
    oos_predictions = engine.predict_oos(test_df, engine.data, z_window=250)
    out_of_sample_results.append(oos_predictions)
    
    # Track the Daily Parameters
    parameter_tracker.append({
        'Date': test_date,
        'Beta': engine.beta,
        'Alpha': engine.alpha,
        'Safe_Variance': engine.safe_variance,
        'Danger_Variance': engine.danger_variance,
        'GARCH_Vol': engine.forecasted_vol,
        'AR_Phi': engine.ar_phi
    })

    # --- NEW: SMART PRINTOUTS ---
    # 1. Print when a new month rolls over
    if i > train_days and test_date.month != unique_days[i-1].month:
        print(f"\n📅 --- ENTERING {test_date.strftime('%B %Y').upper()} ---")
        
    # 2. Print periodic updates (Every N days)
    if i % print_freq == 0:
        print(f"[{test_date}] Beta: {engine.beta:>6.4f} | GARCH Vol: {engine.forecasted_vol:>5.2f} | AR_Phi: {engine.ar_phi:>6.4f}")

# Stitch data together
live_trading_data = pd.concat(out_of_sample_results)
df_params = pd.DataFrame(parameter_tracker).set_index('Date') 

print(f"\n🎉 OOS Dataset Built: {len(live_trading_data)} rows.")
print("📊 Parameter tracking complete.")
# Out:
# Cointegration Fitted | Beta: 0.9434 | Alpha: 0.0690
# Markov Fitted | Danger Variance: 810.85 | Safe Variance: 14.22
# [2025-02-13] Beta: 0.9434 | GARCH Vol:  5.67 | AR_Phi: 0.9400
# Cointegration Fitted | Beta: 0.9442 | Alpha: 0.0695
# Markov Fitted | Danger Variance: 772.83 | Safe Variance: 14.15
# Cointegration Fitted | Beta: 0.9758 | Alpha: 0.0877
# Markov Fitted | Danger Variance: 1121.98 | Safe Variance: 14.88
# Cointegration Fitted | Beta: 0.9785 | Alpha: 0.0892
# Markov Fitted | Danger Variance: 1281.39 | Safe Variance: 14.80
# Cointegration Fitted | Beta: 0.9996 | Alpha: 0.1015
# Markov Fitted | Danger Variance: 1326.49 | Safe Variance: 15.45
# Cointegration Fitted | Beta: 1.0144 | Alpha: 0.1100
# Markov Fitted | Danger Variance: 1134.36 | Safe Variance: 15.15
# Cointegration Fitted | Beta: 1.0424 | Alpha: 0.1261
# Markov Fitted | Danger Variance: 1208.98 | Safe Variance: 15.74
# Cointegration Fitted | Beta: 1.0606 | Alpha: 0.1365
# Markov Fitted | Danger Variance: 1265.09 | Safe Variance: 15.81
# Cointegration Fitted | Beta: 1.0721 | Alpha: 0.1430
# Markov Fitted | Danger Variance: 1276.67 | Safe Variance: 15.89
# Cointegration Fitted | Beta: 1.0563 | Alpha: 0.1341
# Markov Fitted | Danger Variance: 1264.55 | Safe Variance: 15.28
# Cointegration Fitted | Beta: 1.0526 | Alpha: 0.1321
# Markov Fitted | Danger Variance: 1305.67 | Safe Variance: 15.34
# [2025-02-27] Beta: 1.0526 | GARCH Vol:  6.36 | AR_Phi: 0.9515
# Cointegration Fitted | Beta: 1.0728 | Alpha: 0.1434
# Markov Fitted | Danger Variance: 1314.78 | Safe Variance: 15.82
# Cointegration Fitted | Beta: 1.0769 | Alpha: 0.1457
# Markov Fitted | Danger Variance: 1470.63 | Safe Variance: 16.01
#
# 📅 --- ENTERING MARCH 2025 ---
# Cointegration Fitted | Beta: 1.0637 | Alpha: 0.1384
# Markov Fitted | Danger Variance: 1520.90 | Safe Variance: 15.28
# Cointegration Fitted | Beta: 1.0666 | Alpha: 0.1400
# Markov Fitted | Danger Variance: 1380.90 | Safe Variance: 14.73
# Cointegration Fitted | Beta: 1.0585 | Alpha: 0.1353
# Markov Fitted | Danger Variance: 1869.69 | Safe Variance: 15.09
# Cointegration Fitted | Beta: 1.0243 | Alpha: 0.1157
# Markov Fitted | Danger Variance: 1846.19 | Safe Variance: 14.62
# Cointegration Fitted | Beta: 0.9973 | Alpha: 0.1001
# Markov Fitted | Danger Variance: 1560.92 | Safe Variance: 14.69
# Cointegration Fitted | Beta: 0.9673 | Alpha: 0.0830
# Markov Fitted | Danger Variance: 1500.08 | Safe Variance: 14.20
# Cointegration Fitted | Beta: 0.9506 | Alpha: 0.0734
# Markov Fitted | Danger Variance: 1382.39 | Safe Variance: 13.79
# Cointegration Fitted | Beta: 0.9235 | Alpha: 0.0580
# Markov Fitted | Danger Variance: 1372.55 | Safe Variance: 13.77
# [2025-03-13] Beta: 0.9235 | GARCH Vol:  6.41 | AR_Phi: 0.9697
# Cointegration Fitted | Beta: 0.9067 | Alpha: 0.0485
# Markov Fitted | Danger Variance: 1362.84 | Safe Variance: 13.89
# Cointegration Fitted | Beta: 0.8749 | Alpha: 0.0306
# Markov Fitted | Danger Variance: 1362.66 | Safe Variance: 13.73
# Cointegration Fitted | Beta: 0.7635 | Alpha: -0.0322
# Markov Fitted | Danger Variance: 1342.93 | Safe Variance: 12.53
# Cointegration Fitted | Beta: 0.7059 | Alpha: -0.0647
# Markov Fitted | Danger Variance: 1253.41 | Safe Variance: 12.09
# Cointegration Fitted | Beta: 0.6772 | Alpha: -0.0810
# Markov Fitted | Danger Variance: 1230.43 | Safe Variance: 11.96
# Cointegration Fitted | Beta: 0.6552 | Alpha: -0.0935
# Markov Fitted | Danger Variance: 1250.39 | Safe Variance: 12.06
# Cointegration Fitted | Beta: 0.6292 | Alpha: -0.1083
# Markov Fitted | Danger Variance: 1179.06 | Safe Variance: 11.64
# Cointegration Fitted | Beta: 0.6258 | Alpha: -0.1104
# Markov Fitted | Danger Variance: 1136.04 | Safe Variance: 11.61
# Cointegration Fitted | Beta: 0.6302 | Alpha: -0.1081
# Markov Fitted | Danger Variance: 1111.87 | Safe Variance: 11.53
# Cointegration Fitted | Beta: 0.6406 | Alpha: -0.1024
# Markov Fitted | Danger Variance: 1188.59 | Safe Variance: 11.62
# [2025-03-27] Beta: 0.6406 | GARCH Vol:  6.60 | AR_Phi: 0.9829
# Cointegration Fitted | Beta: 0.6507 | Alpha: -0.0969
# Markov Fitted | Danger Variance: 1278.61 | Safe Variance: 11.87
# Cointegration Fitted | Beta: 0.6524 | Alpha: -0.0962
# Markov Fitted | Danger Variance: 889.42 | Safe Variance: 11.85
# Cointegration Fitted | Beta: 0.6686 | Alpha: -0.0875
# Markov Fitted | Danger Variance: 988.55 | Safe Variance: 12.08
#
# 📅 --- ENTERING APRIL 2025 ---
# Cointegration Fitted | Beta: 0.6846 | Alpha: -0.0788
# Markov Fitted | Danger Variance: 1025.90 | Safe Variance: 12.17
# Cointegration Fitted | Beta: 0.6783 | Alpha: -0.0825
# Markov Fitted | Danger Variance: 1033.43 | Safe Variance: 12.26
# Cointegration Fitted | Beta: 0.6232 | Alpha: -0.1138
# Markov Fitted | Danger Variance: 1026.40 | Safe Variance: 12.27
# Cointegration Fitted | Beta: 0.9527 | Alpha: 0.0678
# Markov Fitted | Danger Variance: 3090.23 | Safe Variance: 18.90
# Cointegration Fitted | Beta: 1.2054 | Alpha: 0.2080
# Markov Fitted | Danger Variance: 3845.17 | Safe Variance: 25.53
# Cointegration Fitted | Beta: 1.2717 | Alpha: 0.2445
# Markov Fitted | Danger Variance: 4339.11 | Safe Variance: 27.98
# Cointegration Fitted | Beta: 1.3337 | Alpha: 0.2789
# Markov Fitted | Danger Variance: 4629.41 | Safe Variance: 31.55
# [2025-04-10] Beta: 1.3337 | GARCH Vol:  7.86 | AR_Phi: 0.9841
# Cointegration Fitted | Beta: 1.3222 | Alpha: 0.2714
# Markov Fitted | Danger Variance: 4424.59 | Safe Variance: 31.12
# Cointegration Fitted | Beta: 1.1723 | Alpha: 0.1850
# Markov Fitted | Danger Variance: 4134.48 | Safe Variance: 28.82
# Cointegration Fitted | Beta: 1.1035 | Alpha: 0.1453
# Markov Fitted | Danger Variance: 4094.76 | Safe Variance: 27.32
# Cointegration Fitted | Beta: 1.0415 | Alpha: 0.1096
# Markov Fitted | Danger Variance: 3839.02 | Safe Variance: 26.83
# Cointegration Fitted | Beta: 1.0098 | Alpha: 0.0910
# Markov Fitted | Danger Variance: 3473.58 | Safe Variance: 26.63
# Cointegration Fitted | Beta: 0.9489 | Alpha: 0.0561
# Markov Fitted | Danger Variance: 3312.46 | Safe Variance: 25.80
# Cointegration Fitted | Beta: 0.8626 | Alpha: 0.0067
# Markov Fitted | Danger Variance: 2460.41 | Safe Variance: 20.52
# Cointegration Fitted | Beta: 0.8476 | Alpha: -0.0022
# Markov Fitted | Danger Variance: 2414.96 | Safe Variance: 20.58
# Cointegration Fitted | Beta: 0.8338 | Alpha: -0.0104
# Markov Fitted | Danger Variance: 2365.74 | Safe Variance: 20.53
# Cointegration Fitted | Beta: 0.8269 | Alpha: -0.0149
# Markov Fitted | Danger Variance: 2420.54 | Safe Variance: 21.05
# [2025-04-24] Beta: 0.8269 | GARCH Vol:  8.33 | AR_Phi: 0.9917
# Cointegration Fitted | Beta: 0.8233 | Alpha: -0.0173
# Markov Fitted | Danger Variance: 2383.03 | Safe Variance: 20.97
# Cointegration Fitted | Beta: 0.8218 | Alpha: -0.0186
# Markov Fitted | Danger Variance: 2417.34 | Safe Variance: 21.25
# Cointegration Fitted | Beta: 0.8192 | Alpha: -0.0203
# Markov Fitted | Danger Variance: 2480.11 | Safe Variance: 21.59
# Cointegration Fitted | Beta: 0.8166 | Alpha: -0.0219
# Markov Fitted | Danger Variance: 2483.62 | Safe Variance: 21.63
# Cointegration Fitted | Beta: 0.8172 | Alpha: -0.0218
# Markov Fitted | Danger Variance: 2462.76 | Safe Variance: 21.93
#
# 📅 --- ENTERING MAY 2025 ---
# Cointegration Fitted | Beta: 0.8212 | Alpha: -0.0198
# Markov Fitted | Danger Variance: 2507.80 | Safe Variance: 22.29
# Cointegration Fitted | Beta: 0.8299 | Alpha: -0.0150
# Markov Fitted | Danger Variance: 2514.23 | Safe Variance: 22.90
# Cointegration Fitted | Beta: 0.8392 | Alpha: -0.0099
# Markov Fitted | Danger Variance: 2535.48 | Safe Variance: 22.98
# Cointegration Fitted | Beta: 0.8461 | Alpha: -0.0063
# Markov Fitted | Danger Variance: 2570.03 | Safe Variance: 23.29
# Cointegration Fitted | Beta: 0.8518 | Alpha: -0.0034
# Markov Fitted | Danger Variance: 2621.73 | Safe Variance: 23.64
# [2025-05-08] Beta: 0.8518 | GARCH Vol:  8.19 | AR_Phi: 0.9854
# Cointegration Fitted | Beta: 0.8582 | Alpha: -0.0001
# Markov Fitted | Danger Variance: 2726.49 | Safe Variance: 23.65
# Cointegration Fitted | Beta: 0.8668 | Alpha: 0.0044
# Markov Fitted | Danger Variance: 2760.96 | Safe Variance: 23.79
# Cointegration Fitted | Beta: 0.8789 | Alpha: 0.0110
# Markov Fitted | Danger Variance: 2784.94 | Safe Variance: 24.10
# Cointegration Fitted | Beta: 0.8963 | Alpha: 0.0202
# Markov Fitted | Danger Variance: 2763.42 | Safe Variance: 24.64
# Cointegration Fitted | Beta: 0.9073 | Alpha: 0.0261
# Markov Fitted | Danger Variance: 2701.90 | Safe Variance: 24.52
# Cointegration Fitted | Beta: 0.9094 | Alpha: 0.0270
# Markov Fitted | Danger Variance: 2787.73 | Safe Variance: 24.92
# Cointegration Fitted | Beta: 0.9155 | Alpha: 0.0303
# Markov Fitted | Danger Variance: 1197.08 | Safe Variance: 20.91
# Cointegration Fitted | Beta: 0.9148 | Alpha: 0.0302
# Markov Fitted | Danger Variance: 1142.82 | Safe Variance: 19.84
# Cointegration Fitted | Beta: 0.9037 | Alpha: 0.0245
# Markov Fitted | Danger Variance: 1041.39 | Safe Variance: 18.82
# Cointegration Fitted | Beta: 0.8266 | Alpha: -0.0157
# Markov Fitted | Danger Variance: 1032.64 | Safe Variance: 16.60
# [2025-05-22] Beta: 0.8266 | GARCH Vol:  5.33 | AR_Phi: 0.9895
# Cointegration Fitted | Beta: 0.8112 | Alpha: -0.0235
# Markov Fitted | Danger Variance: 944.39 | Safe Variance: 15.91
# Cointegration Fitted | Beta: 0.5007 | Alpha: -0.1846
# Markov Fitted | Danger Variance: 996.88 | Safe Variance: 13.76
# Cointegration Fitted | Beta: 0.3514 | Alpha: -0.2619
# Markov Fitted | Danger Variance: 734.34 | Safe Variance: 13.44
# Cointegration Fitted | Beta: 0.3460 | Alpha: -0.2643
# Markov Fitted | Danger Variance: 780.13 | Safe Variance: 13.18
# Cointegration Fitted | Beta: 0.3228 | Alpha: -0.2762
# Markov Fitted | Danger Variance: 764.42 | Safe Variance: 12.85
# Cointegration Fitted | Beta: 0.3481 | Alpha: -0.2627
# Markov Fitted | Danger Variance: 772.52 | Safe Variance: 13.02
# Cointegration Fitted | Beta: 0.2869 | Alpha: -0.2934
# Markov Fitted | Danger Variance: 1087.62 | Safe Variance: 16.93
#
# 📅 --- ENTERING JUNE 2025 ---
# Cointegration Fitted | Beta: 0.3616 | Alpha: -0.2543
# Markov Fitted | Danger Variance: 1039.94 | Safe Variance: 16.33
# Cointegration Fitted | Beta: 0.4332 | Alpha: -0.2168
# Markov Fitted | Danger Variance: 1020.48 | Safe Variance: 16.08
# Cointegration Fitted | Beta: 0.5168 | Alpha: -0.1729
# Markov Fitted | Danger Variance: 985.49 | Safe Variance: 15.58
# [2025-06-05] Beta: 0.5168 | GARCH Vol:  6.82 | AR_Phi: 0.9815
# Cointegration Fitted | Beta: 0.6115 | Alpha: -0.1231
# Markov Fitted | Danger Variance: 907.47 | Safe Variance: 15.40
# Cointegration Fitted | Beta: 0.6256 | Alpha: -0.1155
# Markov Fitted | Danger Variance: 840.72 | Safe Variance: 14.87
# Cointegration Fitted | Beta: 0.6377 | Alpha: -0.1089
# Markov Fitted | Danger Variance: 816.78 | Safe Variance: 14.60
# Cointegration Fitted | Beta: 0.6423 | Alpha: -0.1063
# Markov Fitted | Danger Variance: 798.79 | Safe Variance: 14.54
# Cointegration Fitted | Beta: 0.6310 | Alpha: -0.1118
# Markov Fitted | Danger Variance: 785.71 | Safe Variance: 14.28
# Cointegration Fitted | Beta: 0.6158 | Alpha: -0.1195
# Markov Fitted | Danger Variance: 802.31 | Safe Variance: 14.04
# Cointegration Fitted | Beta: 0.6124 | Alpha: -0.1213
# Markov Fitted | Danger Variance: 1005.42 | Safe Variance: 14.05
# Cointegration Fitted | Beta: 0.6193 | Alpha: -0.1177
# Markov Fitted | Danger Variance: 1101.27 | Safe Variance: 14.43
# Cointegration Fitted | Beta: 0.6231 | Alpha: -0.1157
# Markov Fitted | Danger Variance: 1062.87 | Safe Variance: 14.20
# Cointegration Fitted | Beta: 0.6250 | Alpha: -0.1147
# Markov Fitted | Danger Variance: 1027.77 | Safe Variance: 14.20
# [2025-06-19] Beta: 0.6250 | GARCH Vol:  6.18 | AR_Phi: 0.9402
# Cointegration Fitted | Beta: 0.6206 | Alpha: -0.1169
# Markov Fitted | Danger Variance: 835.99 | Safe Variance: 14.11
# Cointegration Fitted | Beta: 0.6209 | Alpha: -0.1167
# Markov Fitted | Danger Variance: 935.38 | Safe Variance: 14.36
# Cointegration Fitted | Beta: 0.6271 | Alpha: -0.1136
# Markov Fitted | Danger Variance: 970.89 | Safe Variance: 14.30
# Cointegration Fitted | Beta: 0.6396 | Alpha: -0.1072
# Markov Fitted | Danger Variance: 1019.93 | Safe Variance: 14.46
# Cointegration Fitted | Beta: 0.6523 | Alpha: -0.1008
# Markov Fitted | Danger Variance: 1013.56 | Safe Variance: 14.66
# Cointegration Fitted | Beta: 0.6950 | Alpha: -0.0789
# Markov Fitted | Danger Variance: 810.70 | Safe Variance: 14.25
# Cointegration Fitted | Beta: 0.7142 | Alpha: -0.0691
# Markov Fitted | Danger Variance: 836.58 | Safe Variance: 14.71
# Cointegration Fitted | Beta: 0.7501 | Alpha: -0.0509
# Markov Fitted | Danger Variance: 880.42 | Safe Variance: 15.14
#
# 📅 --- ENTERING JULY 2025 ---
# Cointegration Fitted | Beta: 0.7687 | Alpha: -0.0414
# Markov Fitted | Danger Variance: 787.28 | Safe Variance: 15.49
# Cointegration Fitted | Beta: 0.8009 | Alpha: -0.0249
# Markov Fitted | Danger Variance: 830.77 | Safe Variance: 16.27
# [2025-07-03] Beta: 0.8009 | GARCH Vol:  6.06 | AR_Phi: 0.9329
# Cointegration Fitted | Beta: 0.8656 | Alpha: 0.0080
# Markov Fitted | Danger Variance: 953.65 | Safe Variance: 17.80
# Cointegration Fitted | Beta: 0.9070 | Alpha: 0.0290
# Markov Fitted | Danger Variance: 775.24 | Safe Variance: 17.73
# Cointegration Fitted | Beta: 0.9020 | Alpha: 0.0265
# Markov Fitted | Danger Variance: 661.74 | Safe Variance: 16.86
# Cointegration Fitted | Beta: 0.8919 | Alpha: 0.0216
# Markov Fitted | Danger Variance: 648.82 | Safe Variance: 16.61
# Cointegration Fitted | Beta: 0.8455 | Alpha: -0.0016
# Markov Fitted | Danger Variance: 585.56 | Safe Variance: 15.68
# Cointegration Fitted | Beta: 0.8072 | Alpha: -0.0206
# Markov Fitted | Danger Variance: 636.97 | Safe Variance: 15.56
# Cointegration Fitted | Beta: 0.7248 | Alpha: -0.0617
# Markov Fitted | Danger Variance: 580.92 | Safe Variance: 14.38
# Cointegration Fitted | Beta: 0.6815 | Alpha: -0.0832
# Markov Fitted | Danger Variance: 598.33 | Safe Variance: 14.38
# Cointegration Fitted | Beta: 0.5787 | Alpha: -0.1346
# Markov Fitted | Danger Variance: 525.48 | Safe Variance: 13.75
# Cointegration Fitted | Beta: 0.5105 | Alpha: -0.1688
# Markov Fitted | Danger Variance: 547.21 | Safe Variance: 13.69
# [2025-07-17] Beta: 0.5105 | GARCH Vol:  6.07 | AR_Phi: 0.9909
# Cointegration Fitted | Beta: 0.5167 | Alpha: -0.1655
# Markov Fitted | Danger Variance: 593.94 | Safe Variance: 13.71
# Cointegration Fitted | Beta: 0.4952 | Alpha: -0.1760
# Markov Fitted | Danger Variance: 669.52 | Safe Variance: 13.42
# Cointegration Fitted | Beta: 0.4909 | Alpha: -0.1780
# Markov Fitted | Danger Variance: 679.54 | Safe Variance: 13.36
# Cointegration Fitted | Beta: 0.4794 | Alpha: -0.1837
# Markov Fitted | Danger Variance: 690.88 | Safe Variance: 13.21
# Cointegration Fitted | Beta: 0.4959 | Alpha: -0.1750
# Markov Fitted | Danger Variance: 731.54 | Safe Variance: 13.35
# Cointegration Fitted | Beta: 0.5394 | Alpha: -0.1523
# Markov Fitted | Danger Variance: 718.51 | Safe Variance: 13.30
# Cointegration Fitted | Beta: 0.5342 | Alpha: -0.1546
# Markov Fitted | Danger Variance: 674.29 | Safe Variance: 13.43
# Cointegration Fitted | Beta: 0.5405 | Alpha: -0.1511
# Markov Fitted | Danger Variance: 705.58 | Safe Variance: 13.27
# Cointegration Fitted | Beta: 0.5587 | Alpha: -0.1416
# Markov Fitted | Danger Variance: 694.20 | Safe Variance: 13.31
# Cointegration Fitted | Beta: 0.5855 | Alpha: -0.1278
# Markov Fitted | Danger Variance: 733.81 | Safe Variance: 13.21
# [2025-07-31] Beta: 0.5855 | GARCH Vol:  6.03 | AR_Phi: 0.9896
# Cointegration Fitted | Beta: 0.5979 | Alpha: -0.1215
# Markov Fitted | Danger Variance: 728.69 | Safe Variance: 13.10
#
# 📅 --- ENTERING AUGUST 2025 ---
# Cointegration Fitted | Beta: 0.5904 | Alpha: -0.1251
# Markov Fitted | Danger Variance: 665.06 | Safe Variance: 13.47
# Cointegration Fitted | Beta: 0.5244 | Alpha: -0.1585
# Markov Fitted | Danger Variance: 627.87 | Safe Variance: 13.23
# Cointegration Fitted | Beta: 0.5400 | Alpha: -0.1503
# Markov Fitted | Danger Variance: 582.16 | Safe Variance: 13.09
# Cointegration Fitted | Beta: 0.5460 | Alpha: -0.1470
# Markov Fitted | Danger Variance: 584.11 | Safe Variance: 13.08
# Cointegration Fitted | Beta: 0.5573 | Alpha: -0.1409
# Markov Fitted | Danger Variance: 616.71 | Safe Variance: 12.75
# Cointegration Fitted | Beta: 0.5832 | Alpha: -0.1273
# Markov Fitted | Danger Variance: 630.75 | Safe Variance: 12.84
# Cointegration Fitted | Beta: 0.6068 | Alpha: -0.1149
# Markov Fitted | Danger Variance: 631.96 | Safe Variance: 12.87
# Cointegration Fitted | Beta: 0.6466 | Alpha: -0.0941
# Markov Fitted | Danger Variance: 656.98 | Safe Variance: 13.34
# Cointegration Fitted | Beta: 0.6909 | Alpha: -0.0711
# Markov Fitted | Danger Variance: 859.36 | Safe Variance: 13.87
# [2025-08-14] Beta: 0.6909 | GARCH Vol:  5.95 | AR_Phi: 0.9728
# Cointegration Fitted | Beta: 0.7355 | Alpha: -0.0476
# Markov Fitted | Danger Variance: 943.98 | Safe Variance: 14.02
# Cointegration Fitted | Beta: 0.7954 | Alpha: -0.0164
# Markov Fitted | Danger Variance: 989.14 | Safe Variance: 14.75
# Cointegration Fitted | Beta: 0.8303 | Alpha: 0.0020
# Markov Fitted | Danger Variance: 1027.88 | Safe Variance: 15.35
# Cointegration Fitted | Beta: 0.8560 | Alpha: 0.0155
# Markov Fitted | Danger Variance: 1057.24 | Safe Variance: 15.64
# Cointegration Fitted | Beta: 0.8157 | Alpha: -0.0052
# Markov Fitted | Danger Variance: 1097.07 | Safe Variance: 15.03
# Cointegration Fitted | Beta: 0.7951 | Alpha: -0.0158
# Markov Fitted | Danger Variance: 1056.67 | Safe Variance: 14.72
# Cointegration Fitted | Beta: 0.7222 | Alpha: -0.0536
# Markov Fitted | Danger Variance: 958.22 | Safe Variance: 13.84
# Cointegration Fitted | Beta: 0.6924 | Alpha: -0.0691
# Markov Fitted | Danger Variance: 900.51 | Safe Variance: 13.46
# Cointegration Fitted | Beta: 0.6548 | Alpha: -0.0886
# Markov Fitted | Danger Variance: 893.49 | Safe Variance: 12.91
# Cointegration Fitted | Beta: 0.6129 | Alpha: -0.1104
# Markov Fitted | Danger Variance: 886.41 | Safe Variance: 12.26
# [2025-08-28] Beta: 0.6129 | GARCH Vol:  5.26 | AR_Phi: 0.9797
# Cointegration Fitted | Beta: 0.5765 | Alpha: -0.1290
# Markov Fitted | Danger Variance: 744.90 | Safe Variance: 11.75
# Cointegration Fitted | Beta: 0.5656 | Alpha: -0.1345
# Markov Fitted | Danger Variance: 655.71 | Safe Variance: 12.10
#
# 📅 --- ENTERING SEPTEMBER 2025 ---
# Cointegration Fitted | Beta: 0.5614 | Alpha: -0.1365
# Markov Fitted | Danger Variance: 651.20 | Safe Variance: 12.19
# Cointegration Fitted | Beta: 0.5197 | Alpha: -0.1580
# Markov Fitted | Danger Variance: 807.70 | Safe Variance: 12.04
# Cointegration Fitted | Beta: 0.4640 | Alpha: -0.1870
# Markov Fitted | Danger Variance: 764.37 | Safe Variance: 11.64
# Cointegration Fitted | Beta: 0.3485 | Alpha: -0.2477
# Markov Fitted | Danger Variance: 742.29 | Safe Variance: 11.47
# Cointegration Fitted | Beta: 0.3016 | Alpha: -0.2718
# Markov Fitted | Danger Variance: 656.04 | Safe Variance: 11.11
# Cointegration Fitted | Beta: 0.3372 | Alpha: -0.2527
# Markov Fitted | Danger Variance: 605.29 | Safe Variance: 10.90
# Cointegration Fitted | Beta: 0.4132 | Alpha: -0.2122
# Markov Fitted | Danger Variance: 609.52 | Safe Variance: 10.89
# Cointegration Fitted | Beta: 0.5178 | Alpha: -0.1562
# Markov Fitted | Danger Variance: 561.86 | Safe Variance: 11.16
# [2025-09-11] Beta: 0.5178 | GARCH Vol:  5.54 | AR_Phi: 0.9959
# Cointegration Fitted | Beta: 0.5930 | Alpha: -0.1157
# Markov Fitted | Danger Variance: 622.17 | Safe Variance: 11.71
# Cointegration Fitted | Beta: 0.6601 | Alpha: -0.0792
# Markov Fitted | Danger Variance: 719.63 | Safe Variance: 11.68
# Cointegration Fitted | Beta: 0.7272 | Alpha: -0.0433
# Markov Fitted | Danger Variance: 813.77 | Safe Variance: 12.25
# Cointegration Fitted | Beta: 0.8045 | Alpha: -0.0019
# Markov Fitted | Danger Variance: 900.32 | Safe Variance: 13.15
# Cointegration Fitted | Beta: 0.8557 | Alpha: 0.0254
# Markov Fitted | Danger Variance: 947.80 | Safe Variance: 14.05
# Cointegration Fitted | Beta: 0.8636 | Alpha: 0.0311
# Markov Fitted | Danger Variance: 1070.97 | Safe Variance: 14.47
# Cointegration Fitted | Beta: 0.8457 | Alpha: 0.0223
# Markov Fitted | Danger Variance: 1089.69 | Safe Variance: 14.36
# Cointegration Fitted | Beta: 0.8438 | Alpha: 0.0220
# Markov Fitted | Danger Variance: 1093.10 | Safe Variance: 14.30
# Cointegration Fitted | Beta: 0.8665 | Alpha: 0.0350
# Markov Fitted | Danger Variance: 1199.91 | Safe Variance: 13.86
# Cointegration Fitted | Beta: 0.8133 | Alpha: 0.0079
# Markov Fitted | Danger Variance: 851.56 | Safe Variance: 12.90
# [2025-09-25] Beta: 0.8133 | GARCH Vol:  5.47 | AR_Phi: 0.9975
# Cointegration Fitted | Beta: 0.7208 | Alpha: -0.0396
# Markov Fitted | Danger Variance: 722.83 | Safe Variance: 11.76
# Cointegration Fitted | Beta: 0.6494 | Alpha: -0.0767
# Markov Fitted | Danger Variance: 645.59 | Safe Variance: 11.24
# Cointegration Fitted | Beta: 0.6124 | Alpha: -0.0958
# Markov Fitted | Danger Variance: 533.40 | Safe Variance: 10.66
# Cointegration Fitted | Beta: 0.5654 | Alpha: -0.1199
# Markov Fitted | Danger Variance: 513.46 | Safe Variance: 10.29
#
# 📅 --- ENTERING OCTOBER 2025 ---
# Cointegration Fitted | Beta: 0.4673 | Alpha: -0.1709
# Markov Fitted | Danger Variance: 472.16 | Safe Variance: 9.79
# Cointegration Fitted | Beta: 0.4104 | Alpha: -0.2006
# Markov Fitted | Danger Variance: 489.95 | Safe Variance: 9.63
# Cointegration Fitted | Beta: 0.3608 | Alpha: -0.2261
# Markov Fitted | Danger Variance: 529.62 | Safe Variance: 9.36
# Cointegration Fitted | Beta: 0.3467 | Alpha: -0.2331
# Markov Fitted | Danger Variance: 513.72 | Safe Variance: 9.36
# Cointegration Fitted | Beta: 0.3284 | Alpha: -0.2425
# Markov Fitted | Danger Variance: 510.61 | Safe Variance: 9.18
# Cointegration Fitted | Beta: 0.2920 | Alpha: -0.2614
# Markov Fitted | Danger Variance: 522.48 | Safe Variance: 9.28
# [2025-10-09] Beta: 0.2920 | GARCH Vol:  5.02 | AR_Phi: 0.9954
# Cointegration Fitted | Beta: 0.2748 | Alpha: -0.2701
# Markov Fitted | Danger Variance: 484.06 | Safe Variance: 9.45
# Cointegration Fitted | Beta: 0.2889 | Alpha: -0.2624
# Markov Fitted | Danger Variance: 467.09 | Safe Variance: 9.37
# Cointegration Fitted | Beta: 0.3194 | Alpha: -0.2461
# Markov Fitted | Danger Variance: 435.27 | Safe Variance: 9.41
# Cointegration Fitted | Beta: 0.3998 | Alpha: -0.2029
# Markov Fitted | Danger Variance: 465.70 | Safe Variance: 9.50
# Cointegration Fitted | Beta: 0.4163 | Alpha: -0.1938
# Markov Fitted | Danger Variance: 487.55 | Safe Variance: 9.62
# Cointegration Fitted | Beta: 0.4388 | Alpha: -0.1815
# Markov Fitted | Danger Variance: 468.99 | Safe Variance: 9.63
# Cointegration Fitted | Beta: 0.5003 | Alpha: -0.1482
# Markov Fitted | Danger Variance: 453.01 | Safe Variance: 10.46
# Cointegration Fitted | Beta: 0.5278 | Alpha: -0.1332
# Markov Fitted | Danger Variance: 453.54 | Safe Variance: 10.72
# Cointegration Fitted | Beta: 0.5662 | Alpha: -0.1124
# Markov Fitted | Danger Variance: 472.01 | Safe Variance: 11.06
# Cointegration Fitted | Beta: 0.6053 | Alpha: -0.0911
# Markov Fitted | Danger Variance: 532.70 | Safe Variance: 11.19
# [2025-10-23] Beta: 0.6053 | GARCH Vol:  3.91 | AR_Phi: 0.9898
# Cointegration Fitted | Beta: 0.6454 | Alpha: -0.0691
# Markov Fitted | Danger Variance: 572.69 | Safe Variance: 11.57
# Cointegration Fitted | Beta: 0.6752 | Alpha: -0.0529
# Markov Fitted | Danger Variance: 570.80 | Safe Variance: 11.87
# Cointegration Fitted | Beta: 0.6932 | Alpha: -0.0429
# Markov Fitted | Danger Variance: 756.29 | Safe Variance: 12.11
# Cointegration Fitted | Beta: 0.7494 | Alpha: -0.0119
# Markov Fitted | Danger Variance: 796.91 | Safe Variance: 12.42
# Cointegration Fitted | Beta: 0.8016 | Alpha: 0.0170
# Markov Fitted | Danger Variance: 847.74 | Safe Variance: 12.60
# Cointegration Fitted | Beta: 0.8518 | Alpha: 0.0450
# Markov Fitted | Danger Variance: 828.44 | Safe Variance: 13.02
# Cointegration Fitted | Beta: 0.8788 | Alpha: 0.0602
# Markov Fitted | Danger Variance: 819.21 | Safe Variance: 13.12
#
# 📅 --- ENTERING NOVEMBER 2025 ---
# Cointegration Fitted | Beta: 0.9003 | Alpha: 0.0723
# Markov Fitted | Danger Variance: 816.81 | Safe Variance: 13.26
# Cointegration Fitted | Beta: 0.8677 | Alpha: 0.0547
# Markov Fitted | Danger Variance: 887.15 | Safe Variance: 12.91
# Cointegration Fitted | Beta: 0.8282 | Alpha: 0.0331
# Markov Fitted | Danger Variance: 862.50 | Safe Variance: 12.47
# [2025-11-06] Beta: 0.8282 | GARCH Vol:  5.24 | AR_Phi: 0.9838
# Cointegration Fitted | Beta: 0.7858 | Alpha: 0.0100
# Markov Fitted | Danger Variance: 783.40 | Safe Variance: 12.23
# Cointegration Fitted | Beta: 0.7119 | Alpha: -0.0305
# Markov Fitted | Danger Variance: 709.88 | Safe Variance: 11.48
# Cointegration Fitted | Beta: 0.6730 | Alpha: -0.0519
# Markov Fitted | Danger Variance: 731.96 | Safe Variance: 11.36
# Cointegration Fitted | Beta: 0.6238 | Alpha: -0.0792
# Markov Fitted | Danger Variance: 687.15 | Safe Variance: 10.94
# Cointegration Fitted | Beta: 0.5476 | Alpha: -0.1216
# Markov Fitted | Danger Variance: 714.23 | Safe Variance: 10.66
# Cointegration Fitted | Beta: 0.4858 | Alpha: -0.1558
# Markov Fitted | Danger Variance: 757.60 | Safe Variance: 10.69
# Cointegration Fitted | Beta: 0.4468 | Alpha: -0.1775
# Markov Fitted | Danger Variance: 838.94 | Safe Variance: 11.26
# Cointegration Fitted | Beta: 0.3898 | Alpha: -0.2094
# Markov Fitted | Danger Variance: 894.19 | Safe Variance: 11.24
# Cointegration Fitted | Beta: 0.3472 | Alpha: -0.2334
# Markov Fitted | Danger Variance: 995.00 | Safe Variance: 11.63
# Cointegration Fitted | Beta: 0.3207 | Alpha: -0.2484
# Markov Fitted | Danger Variance: 987.12 | Safe Variance: 11.57
# [2025-11-20] Beta: 0.3207 | GARCH Vol:  6.13 | AR_Phi: 0.9890
# Cointegration Fitted | Beta: 0.2600 | Alpha: -0.2828
# Markov Fitted | Danger Variance: 1157.20 | Safe Variance: 11.94
# Cointegration Fitted | Beta: 0.3218 | Alpha: -0.2484
# Markov Fitted | Danger Variance: 1199.45 | Safe Variance: 12.16
# Cointegration Fitted | Beta: 0.3421 | Alpha: -0.2370
# Markov Fitted | Danger Variance: 1237.19 | Safe Variance: 12.42
# Cointegration Fitted | Beta: 0.3619 | Alpha: -0.2256
# Markov Fitted | Danger Variance: 1026.99 | Safe Variance: 12.67
# Cointegration Fitted | Beta: 0.3648 | Alpha: -0.2239
# Markov Fitted | Danger Variance: 1139.67 | Safe Variance: 12.64
# Cointegration Fitted | Beta: 0.3807 | Alpha: -0.2148
# Markov Fitted | Danger Variance: 1119.03 | Safe Variance: 12.52
# Cointegration Fitted | Beta: 0.4138 | Alpha: -0.1956
# Markov Fitted | Danger Variance: 1010.86 | Safe Variance: 10.93
#
# 📅 --- ENTERING DECEMBER 2025 ---
# Cointegration Fitted | Beta: 0.4369 | Alpha: -0.1823
# Markov Fitted | Danger Variance: 1048.78 | Safe Variance: 10.88
# Cointegration Fitted | Beta: 0.4617 | Alpha: -0.1680
# Markov Fitted | Danger Variance: 987.16 | Safe Variance: 10.66
# Cointegration Fitted | Beta: 0.5129 | Alpha: -0.1386
# Markov Fitted | Danger Variance: 943.49 | Safe Variance: 10.70
# [2025-12-04] Beta: 0.5129 | GARCH Vol:  6.35 | AR_Phi: 0.9791
# Cointegration Fitted | Beta: 0.5616 | Alpha: -0.1107
# Markov Fitted | Danger Variance: 960.79 | Safe Variance: 10.78
# Cointegration Fitted | Beta: 0.6413 | Alpha: -0.0652
# Markov Fitted | Danger Variance: 1002.94 | Safe Variance: 11.06
# Cointegration Fitted | Beta: 0.6828 | Alpha: -0.0414
# Markov Fitted | Danger Variance: 864.14 | Safe Variance: 11.34
# Cointegration Fitted | Beta: 0.7290 | Alpha: -0.0151
# Markov Fitted | Danger Variance: 856.30 | Safe Variance: 11.65
# Cointegration Fitted | Beta: 0.7601 | Alpha: 0.0027
# Markov Fitted | Danger Variance: 892.93 | Safe Variance: 12.14
# Cointegration Fitted | Beta: 0.7996 | Alpha: 0.0253
# Markov Fitted | Danger Variance: 868.83 | Safe Variance: 12.62
# Cointegration Fitted | Beta: 0.8190 | Alpha: 0.0364
# Markov Fitted | Danger Variance: 891.54 | Safe Variance: 12.90
# Cointegration Fitted | Beta: 0.8282 | Alpha: 0.0417
# Markov Fitted | Danger Variance: 919.34 | Safe Variance: 13.05
# Cointegration Fitted | Beta: 0.8357 | Alpha: 0.0461
# Markov Fitted | Danger Variance: 837.58 | Safe Variance: 13.42
# Cointegration Fitted | Beta: 0.8324 | Alpha: 0.0443
# Markov Fitted | Danger Variance: 941.14 | Safe Variance: 13.53
# [2025-12-18] Beta: 0.8324 | GARCH Vol:  5.75 | AR_Phi: 0.9705
# Cointegration Fitted | Beta: 0.8317 | Alpha: 0.0439
# Markov Fitted | Danger Variance: 1020.05 | Safe Variance: 13.63
# Cointegration Fitted | Beta: 0.8420 | Alpha: 0.0497
# Markov Fitted | Danger Variance: 1049.96 | Safe Variance: 13.71
# Cointegration Fitted | Beta: 0.8563 | Alpha: 0.0576
# Markov Fitted | Danger Variance: 1016.15 | Safe Variance: 13.60
# Cointegration Fitted | Beta: 0.8705 | Alpha: 0.0655
# Markov Fitted | Danger Variance: 1014.44 | Safe Variance: 13.71
# Cointegration Fitted | Beta: 0.8875 | Alpha: 0.0750
# Markov Fitted | Danger Variance: 1059.22 | Safe Variance: 13.67
# Cointegration Fitted | Beta: 0.9162 | Alpha: 0.0909
# Markov Fitted | Danger Variance: 1059.47 | Safe Variance: 13.76
# Cointegration Fitted | Beta: 0.9304 | Alpha: 0.0990
# Markov Fitted | Danger Variance: 1099.91 | Safe Variance: 13.73
# Cointegration Fitted | Beta: 0.9451 | Alpha: 0.1074
# Markov Fitted | Danger Variance: 1134.18 | Safe Variance: 13.99
#
# 🎉 OOS Dataset Built: 13402 rows.
# 📊 Parameter tracking complete.

# %% [markdown]
# ### BACKTESTER

# %%
import importlib
import backtester  

importlib.reload(backtester)
from backtester import BACKTESTER

bt = BACKTESTER(live_trading_data)

results_df = bt.run(
    base_z=1.25, 
    exit_z=0.0, 
    danger_threshold=1.1, 
    ar_limit=0.995, 
    fee_bps=0.5,
    stop_loss_bps=100.0,    
    take_profit_bps=25.0,   
    max_hold_bars=150       
)

# %% [markdown]
# ### TEARSHEET

# %%
ts = TEARSHEET(results_df, df_params=df_params)
ts.generate_report()
ts.plot_comparative_equity()
# Out:
# =======================================================
#            INSTITUTIONAL PERFORMANCE REPORT
# =======================================================
# Metric                    | Adaptive     | Static Base
# -------------------------------------------------------
# Total Return (Bps)        | 2762.69      | 2225.66
# Annual Vol (Bps)          | 705.84       | 748.72
# Sharpe Ratio              | 4.31         | 3.27
# Sortino Ratio             | 4.69         | 3.19
# Max Drawdown (Bps)        | -215.98      | -235.86
# Calmar Ratio              | 12.79        | 9.44
# Win Rate                  | 50.00%       | 50.30%
# Profit Factor             | 1.21         | 1.16
# =======================================================
