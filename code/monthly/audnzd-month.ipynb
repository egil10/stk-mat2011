# %% [markdown]
# # AUDUSD vs NZDUSD — monthly validation
#
# 3-day rolling train → 1-day OOS, EOD flat, fixed trading-rule params.
# Three months across two years: **Aug 2024, Sep 2024, Aug 2025**.
# All pipeline plumbing lives in `code/scripts/month.py`; this notebook just calls it.

# %%
# !curl -sL https://raw.githubusercontent.com/egil10/stk-mat2011/main/code/scripts/colab.py -o /content/colab.py
import sys; sys.path.insert(0, '/content'); from colab import setup; setup('code/monthly')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CWD           : /content/stk-mat2011/code/monthly
# Scripts path  : /content/stk-mat2011/code/scripts
# Data symlink  : /content/stk-mat2011/code/data/processed -> /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/data/processed
# Parquet files : 916

# %%
# %pip install --quiet arch optuna

import warnings; warnings.filterwarnings('ignore')
from month import MONTH

# %%
m = MONTH('AUDUSD', 'NZDUSD')
m.run_months(['202408', '202409', '202508'])
m.summary()
# Out:
# Plots/CSVs will be saved to: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD
#
# --- 202408 ---
# built 2787 rows
# Running Engine | train_days=3 | coint_window=150 | z_window=50 | k_regimes=2 | winsor=4.0σ | scale=x10000
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# [2024-08-23] skipped: Steady-state probabilities could not be constructed.
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   bars=2,787  days=22
#   Sharpe  Baseline=-6.36  AR=-7.49  MS_AR=-5.14
#
# --- 202409 ---
# built 2175 rows
# Running Engine | train_days=3 | coint_window=150 | z_window=50 | k_regimes=2 | winsor=4.0σ | scale=x10000
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   bars=2,175  days=21
#   Sharpe  Baseline=+22.16  AR=+5.65  MS_AR=+20.10
#
# --- 202508 ---
# built 1960 rows
# Running Engine | train_days=3 | coint_window=150 | z_window=50 | k_regimes=2 | winsor=4.0σ | scale=x10000
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   bars=1,960  days=21
#   Sharpe  Baseline=+19.68  AR=-19.40  MS_AR=+1.64
# Saved CSV: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_summary.csv
# === SHARPE BY MONTH (tick-clock annualised) ===
#         Baseline_Sharpe  AR_Sharpe  MS_AR_Sharpe
# Month
# 202408            -6.36      -7.49         -5.14
# 202409            22.16       5.65         20.10
# 202508            19.68     -19.40          1.64
#
# === PnL bps BY MONTH ===
#         Baseline_PnLbps  AR_PnLbps  MS_AR_PnLbps
# Month
# 202408            -98.4      -53.9         -65.5
# 202409            312.9       27.3         220.1
# 202508            200.8      -66.3          13.7
#
# === TRADES BY MONTH ===
#         Baseline_Trades  AR_Trades  MS_AR_Trades
# Month
# 202408               85         46            48
# 202409               93         41            41
# 202508               91         35            39
#
# === EDGE: MS_AR Sharpe minus baseline ===
#         MS_AR vs Baseline  MS_AR vs AR
# Month
# 202408               1.22         2.34
# 202409              -2.06        14.44
# 202508             -18.04        21.03
#
# MS_AR beat Baseline in 1/3 months  |  MS_AR beat AR in 3/3 months

# %%
m.tearsheets()
# Out:
# ==============================  202408  ==============================
#
# =====================================================================================
#                            QUANTITATIVE STRATEGY TEARSHEET
# =====================================================================================
# Metric                         | BuyHold        | Baseline       | AR             | MS_AR          |
# ----------------------------------------------------------------------------------------------------
#
# --- RETURN ---
# Total Return (bps)             | 13.08          | -98.42         | -53.86         | -65.52         |
# Annual Return (bps)            | 199.11         | -1497.76       | -819.69        | -997.08        |
# Best Month (bps)               | 13.08          | -98.42         | -53.86         | -65.52         |
# Worst Month (bps)              | 13.08          | -98.42         | -53.86         | -65.52         |
# Positive Months %              | 100.00%        | 0.00%          | 0.00%          | 0.00%          |
#
# --- RISK ---
# Annual Volatility (bps)        | 954.84         | 814.13         | 378.68         | 670.37         |
# Max Drawdown (bps)             | -175.91        | -219.16        | -91.34         | -130.63        |
# Max DD Duration (bars)         | 738            | 1933           | 1954           | 1884           |
# Ulcer Index                    | 72.04          | 119.88         | 51.01          | 70.07          |
# Value at Risk 95% (bps)        | -8.48          | -7.44          | -2.01          | -6.19          |
# CVaR 95% (bps)                 | -11.54         | -11.22         | -5.31          | -9.84          |
#
# --- RISK-ADJUSTED ---
# Sharpe Ratio                   | 0.21           | -1.84          | -2.16          | -1.49          |
# Sortino Ratio                  | 0.33           | -2.26          | -1.07          | -1.41          |
# Calmar Ratio                   | 1.13           | 6.83           | 8.97           | 7.63           |
# Profit Factor                  | 1.00           | 0.97           | 0.91           | 0.97           |
# Payoff Ratio                   | 1.03           | 1.03           | 1.10           | 1.01           |
# Tail Ratio                     | 1.02           | 1.01           | 0.84           | 1.02           |
#
# --- TRADING ---
# Number of Trades               | 0              | 86             | 46             | 48             |
# Win Rate                       | 49.42%         | 48.37%         | 45.42%         | 48.95%         |
# Market Exposure                | 99.95%         | 72.17%         | 14.79%         | 45.49%         |
# Avg Win (bps)                  | 4.17           | 4.11           | 4.17           | 4.17           |
# Avg Loss (bps)                 | -4.06          | -3.98          | -3.81          | -4.14          |
#
# --- DISTRIBUTION ---
# Skewness                       | 0.30           | -0.26          | -3.20          | -0.39          |
# Kurtosis                       | 3.95           | 8.39           | 76.83          | 17.88          |
# =====================================================================================
#
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202408_performance.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202408_positions_and_regimes.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202408_markov_dynamics.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202408_cost_impact.pdf
# ==============================  202409  ==============================
#
# =====================================================================================
#                            QUANTITATIVE STRATEGY TEARSHEET
# =====================================================================================
# Metric                         | BuyHold        | Baseline       | AR             | MS_AR          |
# ----------------------------------------------------------------------------------------------------
#
# --- RETURN ---
# Total Return (bps)             | 99.21          | 312.89         | 27.28          | 220.08         |
# Annual Return (bps)            | 1449.47        | 4571.26        | 398.54         | 3215.39        |
# Best Month (bps)               | 99.21          | 312.89         | 27.28          | 220.08         |
# Worst Month (bps)              | 99.21          | 312.89         | 27.28          | 220.08         |
# Positive Months %              | 100.00%        | 100.00%        | 100.00%        | 100.00%        |
#
# --- RISK ---
# Annual Volatility (bps)        | 954.42         | 745.67         | 254.89         | 578.35         |
# Max Drawdown (bps)             | -80.17         | -88.95         | -36.34         | -45.31         |
# Max DD Duration (bars)         | 798            | 690            | 1262           | 299            |
# Ulcer Index                    | 33.69          | 32.31          | 16.47          | 16.84          |
# Value at Risk 95% (bps)        | -8.48          | -6.93          | -1.31          | -4.84          |
# CVaR 95% (bps)                 | -11.81         | -9.24          | -3.61          | -7.73          |
#
# --- RISK-ADJUSTED ---
# Sharpe Ratio                   | 1.52           | 6.13           | 1.56           | 5.56           |
# Sortino Ratio                  | 2.39           | 9.49           | 0.99           | 6.69           |
# Calmar Ratio                   | 18.08          | 51.39          | 10.97          | 70.96          |
# Profit Factor                  | 1.02           | 1.13           | 1.08           | 1.16           |
# Payoff Ratio                   | 1.03           | 1.20           | 1.49           | 1.27           |
# Tail Ratio                     | 1.07           | 1.14           | 0.00           | 1.26           |
#
# --- TRADING ---
# Number of Trades               | 0              | 93             | 41             | 41             |
# Win Rate                       | 49.95%         | 48.44%         | 41.90%         | 47.79%         |
# Market Exposure                | 99.95%         | 69.07%         | 9.42%          | 35.67%         |
# Avg Win (bps)                  | 4.35           | 4.41           | 5.05           | 4.80           |
# Avg Loss (bps)                 | -4.23          | -3.68          | -3.38          | -3.77          |
#
# --- DISTRIBUTION ---
# Skewness                       | 0.36           | 1.63           | 1.48           | 3.41           |
# Kurtosis                       | 9.82           | 19.93          | 25.61          | 55.35          |
# =====================================================================================
#
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202409_performance.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202409_positions_and_regimes.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202409_markov_dynamics.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202409_cost_impact.pdf
# ==============================  202508  ==============================
#
# =====================================================================================
#                            QUANTITATIVE STRATEGY TEARSHEET
# =====================================================================================
# Metric                         | BuyHold        | Baseline       | AR             | MS_AR          |
# ----------------------------------------------------------------------------------------------------
#
# --- RETURN ---
# Total Return (bps)             | 184.51         | 200.76         | -66.31         | 13.65          |
# Annual Return (bps)            | 2930.09        | 3188.16        | -1052.99       | 216.84         |
# Best Month (bps)               | 184.51         | 200.76         | -66.31         | 13.65          |
# Worst Month (bps)              | 184.51         | 200.76         | -66.31         | 13.65          |
# Positive Months %              | 100.00%        | 100.00%        | 0.00%          | 100.00%        |
#
# --- RISK ---
# Annual Volatility (bps)        | 814.97         | 614.10         | 205.75         | 501.14         |
# Max Drawdown (bps)             | -76.87         | -115.33        | -96.92         | -133.35        |
# Max DD Duration (bars)         | 570            | 600            | 1486           | 702            |
# Ulcer Index                    | 30.06          | 44.75          | 67.44          | 57.45          |
# Value at Risk 95% (bps)        | -8.11          | -5.72          | -0.68          | -5.09          |
# CVaR 95% (bps)                 | -10.80         | -8.64          | -3.29          | -8.12          |
#
# --- RISK-ADJUSTED ---
# Sharpe Ratio                   | 3.60           | 5.19           | -5.12          | 0.43           |
# Sortino Ratio                  | 5.78           | 6.87           | -2.60          | 0.41           |
# Calmar Ratio                   | 38.12          | 27.64          | 10.86          | 1.63           |
# Profit Factor                  | 1.06           | 1.11           | 0.75           | 1.01           |
# Payoff Ratio                   | 1.02           | 1.16           | 1.18           | 1.07           |
# Tail Ratio                     | 1.03           | 1.31           | 0.00           | 1.12           |
#
# --- TRADING ---
# Number of Trades               | 0              | 92             | 35             | 39             |
# Win Rate                       | 50.98%         | 49.00%         | 38.85%         | 48.60%         |
# Market Exposure                | 99.75%         | 66.31%         | 8.74%          | 40.35%         |
# Avg Win (bps)                  | 3.90           | 3.87           | 3.70           | 3.86           |
# Avg Loss (bps)                 | -3.82          | -3.34          | -3.13          | -3.61          |
#
# --- DISTRIBUTION ---
# Skewness                       | 0.27           | 0.03           | 0.52           | -0.50          |
# Kurtosis                       | 1.99           | 5.53           | 48.50          | 11.70          |
# =====================================================================================
#
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202508_performance.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202508_positions_and_regimes.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202508_markov_dynamics.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_202508_cost_impact.pdf

# %%
m.sweep('202408')
# Out:
# built 2787 rows
# Running Engine | train_days=3 | coint_window=150 | z_window=50 | k_regimes=2 | winsor=4.0σ | scale=x10000
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# [2024-08-23] skipped: Steady-state probabilities could not be constructed.
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# === Sensitivity sweep, 202408, AUDUSD_NZDUSD ===
#  z_quiet  z_volatile  danger_threshold  Baseline_Sharpe  AR_Sharpe  MS_AR_Sharpe  MS_AR_Trades  MS_AR_vs_AR  MS_AR_vs_Baseline
#      1.0         2.0              0.15            -6.77      -5.65         -4.13            74         1.51               2.64
#      1.0         2.0              0.30            -6.77     -10.35         -4.13            74         6.22               2.64
#      1.0         2.0              0.50            -6.77      -6.76         -4.13            74         2.62               2.64
#      1.0         2.5              0.15            -6.77      -5.65         -5.91            59        -0.26               0.86
#      1.0         2.5              0.30            -6.77     -10.35         -5.91            59         4.44               0.86
#      1.0         2.5              0.50            -6.77      -6.76         -5.91            59         0.84               0.86
#      1.0         3.5              0.15            -6.77      -5.65         -8.09            42        -2.44              -1.32
#      1.0         3.5              0.30            -6.77     -10.35         -8.09            42         2.26              -1.32
#      1.0         3.5              0.50            -6.77      -6.76         -8.09            42        -1.34              -1.32
#      1.3         2.0              0.15            -6.36      -1.27         -1.84            64        -0.56               4.53
#      1.3         2.0              0.30            -6.36      -7.49         -1.84            64         5.65               4.53
#      1.3         2.0              0.50            -6.36      -1.63         -1.84            64        -0.21               4.53
#      1.3         2.5              0.15            -6.36      -1.27         -5.14            48        -3.87               1.22
#      1.3         2.5              0.30            -6.36      -7.49         -5.14            48         2.34               1.22
#      1.3         2.5              0.50            -6.36      -1.63         -5.14            48        -3.51               1.22
#      1.3         3.5              0.15            -6.36      -1.27         -5.70            33        -4.42               0.67
#      1.3         3.5              0.30            -6.36      -7.49         -5.70            33         1.79               0.67
#      1.3         3.5              0.50            -6.36      -1.63         -5.70            33        -4.07               0.67
#      1.6         2.0              0.15            -8.09       3.21          0.33            60        -2.88               8.42
#      1.6         2.0              0.30            -8.09      -2.80          0.33            60         3.13               8.42
#      1.6         2.0              0.50            -8.09      -0.81          0.33            60         1.14               8.42
#      1.6         2.5              0.15            -8.09       3.21         -2.17            45        -5.38               5.92
#      1.6         2.5              0.30            -8.09      -2.80         -2.17            45         0.63               5.92
#      1.6         2.5              0.50            -8.09      -0.81         -2.17            45        -1.36               5.92
#      1.6         3.5              0.15            -8.09       3.21         -0.29            28        -3.50               7.80
#      1.6         3.5              0.30            -8.09      -2.80         -0.29            28         2.51               7.80
#      1.6         3.5              0.50            -8.09      -0.81         -0.29            28         0.52               7.80
#
# MS_AR > AR       across grid: 14/27
# MS_AR > Baseline across grid: 24/27
# Saved CSV: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/AUDUSD_NZDUSD/AUDUSD_NZDUSD_sweep_202408.csv
#     z_quiet  z_volatile  danger_threshold  Baseline_Sharpe  AR_Sharpe  \
# 0       1.0         2.0              0.15        -6.774916  -5.647322
# 1       1.0         2.0              0.30        -6.774916 -10.352283
# 2       1.0         2.0              0.50        -6.774916  -6.755803
# 3       1.0         2.5              0.15        -6.774916  -5.647322
# 4       1.0         2.5              0.30        -6.774916 -10.352283
# 5       1.0         2.5              0.50        -6.774916  -6.755803
# 6       1.0         3.5              0.15        -6.774916  -5.647322
# 7       1.0         3.5              0.30        -6.774916 -10.352283
# 8       1.0         3.5              0.50        -6.774916  -6.755803
# 9       1.3         2.0              0.15        -6.361771  -1.272582
# 10      1.3         2.0              0.30        -6.361771  -7.485235
# 11      1.3         2.0              0.50        -6.361771  -1.629798
# 12      1.3         2.5              0.15        -6.361771  -1.272582
# 13      1.3         2.5              0.30        -6.361771  -7.485235
# 14      1.3         2.5              0.50        -6.361771  -1.629798
# 15      1.3         3.5              0.15        -6.361771  -1.272582
# 16      1.3         3.5              0.30        -6.361771  -7.485235
# 17      1.3         3.5              0.50        -6.361771  -1.629798
# 18      1.6         2.0              0.15        -8.091495   3.207059
# 19      1.6         2.0              0.30        -8.091495  -2.801594
# 20      1.6         2.0              0.50        -8.091495  -0.813108
# 21      1.6         2.5              0.15        -8.091495   3.207059
# 22      1.6         2.5              0.30        -8.091495  -2.801594
# 23      1.6         2.5              0.50        -8.091495  -0.813108
# 24      1.6         3.5              0.15        -8.091495   3.207059
# 25      1.6         3.5              0.30        -8.091495  -2.801594
# 26      1.6         3.5              0.50        -8.091495  -0.813108
#
#     MS_AR_Sharpe  MS_AR_Trades  MS_AR_vs_AR  MS_AR_vs_Baseline
# 0      -4.132880            74     1.514442           2.642036
# 1      -4.132880            74     6.219403           2.642036
# 2      -4.132880            74     2.622923           2.642036
# 3      -5.912281            59    -0.264959           0.862635
# 4      -5.912281            59     4.440002           0.862635
# 5      -5.912281            59     0.843522           0.862635
# 6      -8.091242            42    -2.443920          -1.316326
# 7      -8.091242            42     2.261042          -1.316326
# 8      -8.091242            42    -1.335439          -1.316326
# 9      -1.835663            64    -0.563082           4.526107
# 10     -1.835663            64     5.649572           4.526107
# 11     -1.835663            64    -0.205865           4.526107
# 12     -5.143362            48    -3.870781           1.218408
# 13     -5.143362            48     2.341873           1.218408
# 14     -5.143362            48    -3.513564           1.218408
# 15     -5.695538            33    -4.422957           0.666232
# 16     -5.695538            33     1.789697           0.666232
# 17     -5.695538            33    -4.065740           0.666232
# 18      0.331611            60    -2.875448           8.423105
# 19      0.331611            60     3.133205           8.423105
# 20      0.331611            60     1.144719           8.423105
# 21     -2.169109            45    -5.376167           5.922386
# 22     -2.169109            45     0.632485           5.922386
# 23     -2.169109            45    -1.356000           5.922386
# 24     -0.290648            28    -3.497707           7.800846
# 25     -0.290648            28     2.510946           7.800846
# 26     -0.290648            28     0.522460           7.800846
