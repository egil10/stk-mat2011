# %% [markdown]
# # GBPUSD vs EURUSD — monthly validation
#
# 3-day rolling train → 1-day OOS, EOD flat, fixed trading-rule params.
# Three months across two years: **Aug 2024, Sep 2024, Aug 2025**.
# All pipeline plumbing lives in `code/scripts/month.py`; this notebook just calls it.

# %%
# !curl -sL https://raw.githubusercontent.com/egil10/stk-mat2011/main/code/scripts/colab.py -o /content/colab.py
import sys; sys.path.insert(0, '/content'); from colab import setup; setup('code/monthly')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CWD           : /content/stk-mat2011/code/monthly
# Scripts path  : /content/stk-mat2011/code/scripts
# Data symlink  : /content/stk-mat2011/code/data/processed -> /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/data/processed
# Parquet files : 916

# %%
# %pip install --quiet arch optuna

import warnings; warnings.filterwarnings('ignore')
from month import MONTH

# %%
m = MONTH('GBPUSD', 'EURUSD')
m.run_months(['202408', '202409', '202508'])
m.summary()
# Out:
# Plots/CSVs will be saved to: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/GBPUSD_EURUSD
# Engine: train_days=3 | coint_window=150 | z_window=50 | k_regimes=2 | winsor=4.0σ | scale=x10000
# [2024-08-19] skipped: Steady-state probabilities could not be constructed.
# 202408  bars=3,470  days=22  | Sharpe  B= -0.49  AR=+23.53  MS= +4.39
# 202409  bars=3,818  days=21  | Sharpe  B=+19.13  AR= +8.34  MS=+16.98
# 202508  bars=2,884  days=21  | Sharpe  B= +4.81  AR=-22.73  MS= +1.23
# === SHARPE BY MONTH (tick-clock annualised) ===
#         Baseline_Sharpe  AR_Sharpe  MS_AR_Sharpe
# Month
# 202408            -0.49      23.53          4.39
# 202409            19.13       8.34         16.98
# 202508             4.81     -22.73          1.23
#
# === PnL bps BY MONTH ===
#         Baseline_PnLbps  AR_PnLbps  MS_AR_PnLbps
# Month
# 202408             -5.9       44.0          39.1
# 202409            321.8       50.4         243.8
# 202508             52.4     -106.7          11.4
#
# === TRADES BY MONTH ===
#         Baseline_Trades  AR_Trades  MS_AR_Trades
# Month
# 202408               93         19            46
# 202409              141         51            78
# 202508               98         36            48
#
# === EDGE: MS_AR Sharpe minus baseline ===
#         MS_AR vs Baseline  MS_AR vs AR
# Month
# 202408               4.89       -19.13
# 202409              -2.14         8.64
# 202508              -3.57        23.96
#
# MS_AR beat Baseline in 1/3 months  |  MS_AR beat AR in 2/3 months

# %%
m.tearsheets()
# Out:
# ==============================  202408  ==============================
#
# =====================================================================================
#                            QUANTITATIVE STRATEGY TEARSHEET
# =====================================================================================
# Metric                         | BuyHold        | Baseline       | AR             | MS_AR          |
# ----------------------------------------------------------------------------------------------------
#
# --- RETURN ---
# Total Return (bps)             | 215.62         | -5.88          | 44.05          | 39.15          |
# Annual Return (bps)            | 3281.45        | -89.47         | 670.32         | 595.78         |
# Best Month (bps)               | 215.62         | -5.88          | 44.05          | 39.15          |
# Worst Month (bps)              | 215.62         | -5.88          | 44.05          | 39.15          |
# Positive Months %              | 100.00%        | 0.00%          | 100.00%        | 100.00%        |
#
# --- RISK ---
# Annual Volatility (bps)        | 678.77         | 553.07         | 86.82          | 413.11         |
# Max Drawdown (bps)             | -93.76         | -117.42        | -8.27          | -66.71         |
# Max DD Duration (bars)         | 623            | 2318           | 824            | 1335           |
# Ulcer Index                    | 36.63          | 54.78          | 2.43           | 28.88          |
# Value at Risk 95% (bps)        | -5.48          | -4.95          | 0.00           | -3.37          |
# CVaR 95% (bps)                 | -7.61          | -6.65          | -0.02          | -5.59          |
#
# --- RISK-ADJUSTED ---
# Sharpe Ratio                   | 4.83           | -0.16          | 7.72           | 1.44           |
# Sortino Ratio                  | 7.26           | -0.21          | 3.91           | 1.35           |
# Calmar Ratio                   | 35.00          | 0.76           | 81.02          | 8.93           |
# Profit Factor                  | 1.07           | 1.00           | 1.82           | 1.03           |
# Payoff Ratio                   | 1.04           | 1.05           | 2.16           | 1.03           |
# Tail Ratio                     | 1.01           | 0.97           | NaN            | 1.06           |
#
# --- TRADING ---
# Number of Trades               | 0              | 94             | 19             | 46             |
# Win Rate                       | 50.70%         | 48.80%         | 45.78%         | 49.95%         |
# Market Exposure                | 99.77%         | 69.98%         | 3.23%          | 37.11%         |
# Avg Win (bps)                  | 2.64           | 2.59           | 2.57           | 2.63           |
# Avg Loss (bps)                 | -2.54          | -2.47          | -1.19          | -2.55          |
#
# --- DISTRIBUTION ---
# Skewness                       | -0.07          | -0.01          | 8.52           | 0.06           |
# Kurtosis                       | 2.17           | 3.30           | 138.92         | 9.30           |
# =====================================================================================
#   saved 4 plots → /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/GBPUSD_EURUSD
#
# ==============================  202409  ==============================
#
# =====================================================================================
#                            QUANTITATIVE STRATEGY TEARSHEET
# =====================================================================================
# Metric                         | BuyHold        | Baseline       | AR             | MS_AR          |
# ----------------------------------------------------------------------------------------------------
#
# --- RETURN ---
# Total Return (bps)             | 151.06         | 321.78         | 50.41          | 243.84         |
# Annual Return (bps)            | 2206.94        | 4701.22        | 736.55         | 3562.55        |
# Best Month (bps)               | 151.06         | 321.78         | 50.41          | 243.84         |
# Worst Month (bps)              | 151.06         | 321.78         | 50.41          | 243.84         |
# Positive Months %              | 100.00%        | 100.00%        | 100.00%        | 100.00%        |
#
# --- RISK ---
# Annual Volatility (bps)        | 827.62         | 662.68         | 238.07         | 565.52         |
# Max Drawdown (bps)             | -86.29         | -87.08         | -29.51         | -61.03         |
# Max DD Duration (bars)         | 1300           | 744            | 1343           | 681            |
# Ulcer Index                    | 39.87          | 26.63          | 13.29          | 15.89          |
# Value at Risk 95% (bps)        | -5.49          | -4.19          | 0.00           | -3.61          |
# CVaR 95% (bps)                 | -7.99          | -6.49          | -0.07          | -5.64          |
#
# --- RISK-ADJUSTED ---
# Sharpe Ratio                   | 2.67           | 7.09           | 3.09           | 6.30           |
# Sortino Ratio                  | 3.60           | 9.24           | 2.10           | 7.28           |
# Calmar Ratio                   | 25.58          | 53.99          | 24.96          | 58.37          |
# Profit Factor                  | 1.04           | 1.12           | 1.21           | 1.13           |
# Payoff Ratio                   | 0.98           | 1.20           | 1.69           | 1.24           |
# Tail Ratio                     | 0.98           | 1.17           | NaN            | 1.14           |
#
# --- TRADING ---
# Number of Trades               | 0              | 141            | 51             | 78             |
# Win Rate                       | 51.35%         | 48.21%         | 41.77%         | 47.66%         |
# Market Exposure                | 99.80%         | 68.83%         | 6.94%          | 45.74%         |
# Avg Win (bps)                  | 2.54           | 2.73           | 2.94           | 2.91           |
# Avg Loss (bps)                 | -2.59          | -2.28          | -1.75          | -2.36          |
#
# --- DISTRIBUTION ---
# Skewness                       | -0.68          | 1.25           | 22.70          | 2.35           |
# Kurtosis                       | 31.77          | 23.85          | 939.75         | 40.67          |
# =====================================================================================
#   saved 4 plots → /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/GBPUSD_EURUSD
#
# ==============================  202508  ==============================
#
# =====================================================================================
#                            QUANTITATIVE STRATEGY TEARSHEET
# =====================================================================================
# Metric                         | BuyHold        | Baseline       | AR             | MS_AR          |
# ----------------------------------------------------------------------------------------------------
#
# --- RETURN ---
# Total Return (bps)             | 55.77          | 52.39          | -106.67        | 11.43          |
# Annual Return (bps)            | 885.70         | 831.94         | -1694.02       | 181.59         |
# Best Month (bps)               | 55.77          | 52.39          | -106.67        | 11.43          |
# Worst Month (bps)              | 55.77          | 52.39          | -106.67        | 11.43          |
# Positive Months %              | 100.00%        | 100.00%        | 0.00%          | 100.00%        |
#
# --- RISK ---
# Annual Volatility (bps)        | 645.40         | 540.40         | 232.75         | 459.50         |
# Max Drawdown (bps)             | -170.18        | -111.52        | -132.79        | -93.75         |
# Max DD Duration (bars)         | 1487           | 1512           | 1959           | 1168           |
# Ulcer Index                    | 90.36          | 45.73          | 76.08          | 38.79          |
# Value at Risk 95% (bps)        | -5.32          | -4.30          | -1.46          | -3.63          |
# CVaR 95% (bps)                 | -7.41          | -6.83          | -3.47          | -6.01          |
#
# --- RISK-ADJUSTED ---
# Sharpe Ratio                   | 1.37           | 1.54           | -7.28          | 0.40           |
# Sortino Ratio                  | 2.03           | 1.79           | -4.64          | 0.39           |
# Calmar Ratio                   | 5.20           | 7.46           | 12.76          | 1.94           |
# Profit Factor                  | 1.02           | 1.03           | 0.78           | 1.01           |
# Payoff Ratio                   | 1.01           | 1.08           | 1.07           | 1.06           |
# Tail Ratio                     | 1.00           | 1.09           | 0.66           | 1.09           |
#
# --- TRADING ---
# Number of Trades               | 0              | 98             | 36             | 48             |
# Win Rate                       | 50.34%         | 48.82%         | 42.19%         | 48.80%         |
# Market Exposure                | 99.91%         | 67.02%         | 16.38%         | 46.08%         |
# Avg Win (bps)                  | 2.48           | 2.59           | 2.37           | 2.62           |
# Avg Loss (bps)                 | -2.47          | -2.41          | -2.21          | -2.48          |
#
# --- DISTRIBUTION ---
# Skewness                       | 0.03           | -0.34          | -0.40          | -0.26          |
# Kurtosis                       | 3.64           | 8.25           | 21.33          | 13.94          |
# =====================================================================================
#   saved 4 plots → /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/GBPUSD_EURUSD

# %%
m.sweep('202408')
# Out:
# [2024-08-19] skipped: Steady-state probabilities could not be constructed.
# === Sensitivity sweep, 202408, GBPUSD_EURUSD ===
#  z_quiet  z_volatile  danger_threshold  Baseline_Sharpe  AR_Sharpe  MS_AR_Sharpe  MS_AR_Trades  MS_AR_vs_AR  MS_AR_vs_Baseline
#      1.0         2.0              0.15             2.58      12.02          1.74            68       -10.28              -0.84
#      1.0         2.0              0.30             2.58      19.23          1.74            68       -17.49              -0.84
#      1.0         2.0              0.50             2.58       7.08          1.74            68        -5.33              -0.84
#      1.0         2.5              0.15             2.58      12.02          6.44            51        -5.58               3.86
#      1.0         2.5              0.30             2.58      19.23          6.44            51       -12.80               3.86
#      1.0         2.5              0.50             2.58       7.08          6.44            51        -0.64               3.86
#      1.0         3.5              0.15             2.58      12.02          8.80            26        -3.22               6.21
#      1.0         3.5              0.30             2.58      19.23          8.80            26       -10.44               6.21
#      1.0         3.5              0.50             2.58       7.08          8.80            26         1.72               6.21
#      1.3         2.0              0.15            -0.49      16.76          0.80            65       -15.95               1.30
#      1.3         2.0              0.30            -0.49      23.53          0.80            65       -22.72               1.30
#      1.3         2.0              0.50            -0.49       7.94          0.80            65        -7.13               1.30
#      1.3         2.5              0.15            -0.49      16.76          4.39            46       -12.36               4.89
#      1.3         2.5              0.30            -0.49      23.53          4.39            46       -19.13               4.89
#      1.3         2.5              0.50            -0.49       7.94          4.39            46        -3.54               4.89
#      1.3         3.5              0.15            -0.49      16.76          6.78            23        -9.98               7.27
#      1.3         3.5              0.30            -0.49      23.53          6.78            23       -16.75               7.27
#      1.3         3.5              0.50            -0.49       7.94          6.78            23        -1.16               7.27
#      1.6         2.0              0.15            -1.51      11.11         -0.27            60       -11.38               1.23
#      1.6         2.0              0.30            -1.51      21.09         -0.27            60       -21.36               1.23
#      1.6         2.0              0.50            -1.51       7.11         -0.27            60        -7.38               1.23
#      1.6         2.5              0.15            -1.51      11.11          3.35            42        -7.76               4.86
#      1.6         2.5              0.30            -1.51      21.09          3.35            42       -17.73               4.86
#      1.6         2.5              0.50            -1.51       7.11          3.35            42        -3.75               4.86
#      1.6         3.5              0.15            -1.51      11.11          8.91            21        -2.20              10.41
#      1.6         3.5              0.30            -1.51      21.09          8.91            21       -12.18              10.41
#      1.6         3.5              0.50            -1.51       7.11          8.91            21         1.80              10.41
#
# MS_AR > AR       across grid: 2/27
# MS_AR > Baseline across grid: 24/27
#     z_quiet  z_volatile  danger_threshold  Baseline_Sharpe  AR_Sharpe  \
# 0       1.0         2.0              0.15         2.581454  12.019460
# 1       1.0         2.0              0.30         2.581454  19.233155
# 2       1.0         2.0              0.50         2.581454   7.075645
# 3       1.0         2.5              0.15         2.581454  12.019460
# 4       1.0         2.5              0.30         2.581454  19.233155
# 5       1.0         2.5              0.50         2.581454   7.075645
# 6       1.0         3.5              0.15         2.581454  12.019460
# 7       1.0         3.5              0.30         2.581454  19.233155
# 8       1.0         3.5              0.50         2.581454   7.075645
# 9       1.3         2.0              0.15        -0.492952  16.755314
# 10      1.3         2.0              0.30        -0.492952  23.525606
# 11      1.3         2.0              0.50        -0.492952   7.936245
# 12      1.3         2.5              0.15        -0.492952  16.755314
# 13      1.3         2.5              0.30        -0.492952  23.525606
# 14      1.3         2.5              0.50        -0.492952   7.936245
# 15      1.3         3.5              0.15        -0.492952  16.755314
# 16      1.3         3.5              0.30        -0.492952  23.525606
# 17      1.3         3.5              0.50        -0.492952   7.936245
# 18      1.6         2.0              0.15        -1.505061  11.112694
# 19      1.6         2.0              0.30        -1.505061  21.085225
# 20      1.6         2.0              0.50        -1.505061   7.105360
# 21      1.6         2.5              0.15        -1.505061  11.112694
# 22      1.6         2.5              0.30        -1.505061  21.085225
# 23      1.6         2.5              0.50        -1.505061   7.105360
# 24      1.6         3.5              0.15        -1.505061  11.112694
# 25      1.6         3.5              0.30        -1.505061  21.085225
# 26      1.6         3.5              0.50        -1.505061   7.105360
#
#     MS_AR_Sharpe  MS_AR_Trades  MS_AR_vs_AR  MS_AR_vs_Baseline
# 0       1.743790            68   -10.275670          -0.837664
# 1       1.743790            68   -17.489365          -0.837664
# 2       1.743790            68    -5.331855          -0.837664
# 3       6.437104            51    -5.582356           3.855650
# 4       6.437104            51   -12.796051           3.855650
# 5       6.437104            51    -0.638541           3.855650
# 6       8.795344            26    -3.224116           6.213890
# 7       8.795344            26   -10.437811           6.213890
# 8       8.795344            26     1.719699           6.213890
# 9       0.803057            65   -15.952258           1.296008
# 10      0.803057            65   -22.722550           1.296008
# 11      0.803057            65    -7.133189           1.296008
# 12      4.394520            46   -12.360794           4.887472
# 13      4.394520            46   -19.131086           4.887472
# 14      4.394520            46    -3.541725           4.887472
# 15      6.775702            23    -9.979613           7.268653
# 16      6.775702            23   -16.749905           7.268653
# 17      6.775702            23    -1.160544           7.268653
# 18     -0.272089            60   -11.384783           1.232972
# 19     -0.272089            60   -21.357314           1.232972
# 20     -0.272089            60    -7.377449           1.232972
# 21      3.350454            42    -7.762240           4.855516
# 22      3.350454            42   -17.734770           4.855516
# 23      3.350454            42    -3.754906           4.855516
# 24      8.909847            21    -2.202847          10.414909
# 25      8.909847            21   -12.175377          10.414909
# 26      8.909847            21     1.804488          10.414909
