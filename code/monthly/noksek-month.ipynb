# %% [markdown]
# # EURNOK vs EURSEK — monthly validation
#
# 3-day rolling train → 1-day OOS, EOD flat, fixed trading-rule params.
# Three months across two years: **Aug 2024, Sep 2024, Aug 2025**.
# All pipeline plumbing lives in `code/scripts/month.py`; this notebook just calls it.

# %%
# !curl -sL https://raw.githubusercontent.com/egil10/stk-mat2011/main/code/scripts/colab.py -o /content/colab.py
import sys; sys.path.insert(0, '/content'); from colab import setup; setup('code/monthly')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CWD           : /content/stk-mat2011/code/monthly
# Scripts path  : /content/stk-mat2011/code/scripts
# Data symlink  : /content/stk-mat2011/code/data/processed -> /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/data/processed
# Parquet files : 916

# %%
# %pip install --quiet arch optuna

import warnings; warnings.filterwarnings('ignore')
from month import MONTH

# %%
m = MONTH('EURNOK', 'EURSEK')
m.run_months(['202408', '202409', '202508'])
m.summary()
# Out:
# Plots/CSVs will be saved to: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK
#
# --- 202408 ---
# built 9088 rows
# Running Engine | train_days=3 | coint_window=150 | z_window=50 | k_regimes=2 | winsor=4.0σ | scale=x10000
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   bars=9,088  days=22
#   Sharpe  Baseline=-43.87  AR=-87.82  MS_AR=-37.44
#
# --- 202409 ---
# built 9465 rows
# Running Engine | train_days=3 | coint_window=150 | z_window=50 | k_regimes=2 | winsor=4.0σ | scale=x10000
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   bars=9,465  days=21
#   Sharpe  Baseline=-52.10  AR=-103.30  MS_AR=-44.07
#
# --- 202508 ---
# built 2886 rows
# Running Engine | train_days=3 | coint_window=150 | z_window=50 | k_regimes=2 | winsor=4.0σ | scale=x10000
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   bars=2,886  days=21
#   Sharpe  Baseline=-43.35  AR=-54.48  MS_AR=-31.45
# Saved CSV: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_summary.csv
# === SHARPE BY MONTH (tick-clock annualised) ===
#         Baseline_Sharpe  AR_Sharpe  MS_AR_Sharpe
# Month
# 202408           -43.87     -87.82        -37.44
# 202409           -52.10    -103.30        -44.07
# 202508           -43.35     -54.48        -31.45
#
# === PnL bps BY MONTH ===
#         Baseline_PnLbps  AR_PnLbps  MS_AR_PnLbps
# Month
# 202408          -2287.7    -2117.5       -1583.0
# 202409          -2202.4    -2074.4       -1531.9
# 202508           -664.9     -255.5        -349.4
#
# === TRADES BY MONTH ===
#         Baseline_Trades  AR_Trades  MS_AR_Trades
# Month
# 202408              285        227           183
# 202409              319        243           185
# 202508               95         29            44
#
# === EDGE: MS_AR Sharpe minus baseline ===
#         MS_AR vs Baseline  MS_AR vs AR
# Month
# 202408               6.43        50.38
# 202409               8.03        59.23
# 202508              11.91        23.03
#
# MS_AR beat Baseline in 3/3 months  |  MS_AR beat AR in 3/3 months

# %%
m.tearsheets()
# Out:
# ==============================  202408  ==============================
#
# =====================================================================================
#                            QUANTITATIVE STRATEGY TEARSHEET
# =====================================================================================
# Metric                         | BuyHold        | Baseline       | AR             | MS_AR          |
# ----------------------------------------------------------------------------------------------------
#
# --- RETURN ---
# Total Return (bps)             | -267.79        | -2287.65       | -2117.48       | -1582.96       |
# Annual Return (bps)            | -4075.49       | -34815.21      | -32225.46      | -24090.64      |
# Best Month (bps)               | -267.79        | -2287.65       | -2117.48       | -1582.96       |
# Worst Month (bps)              | -267.79        | -2287.65       | -2117.48       | -1582.96       |
# Positive Months %              | 0.00%          | 0.00%          | 0.00%          | 0.00%          |
#
# --- RISK ---
# Annual Volatility (bps)        | 1217.70        | 1441.62        | 666.60         | 1168.95        |
# Max Drawdown (bps)             | -330.77        | -2311.58       | -2117.48       | -1641.80       |
# Max DD Duration (bars)         | 7182           | 7216           | 7180           | 6836           |
# Ulcer Index                    | 229.04         | 1528.99        | 1155.17        | 1057.80        |
# Value at Risk 95% (bps)        | -5.79          | -5.73          | -2.80          | -4.60          |
# CVaR 95% (bps)                 | -8.80          | -11.11         | -6.28          | -9.20          |
#
# --- RISK-ADJUSTED ---
# Sharpe Ratio                   | -3.35          | -24.15         | -48.34         | -20.61         |
# Sortino Ratio                  | -4.40          | -19.37         | -20.60         | -13.88         |
# Calmar Ratio                   | 12.32          | 15.06          | 15.22          | 14.67          |
# Profit Factor                  | 0.97           | 0.72           | 0.23           | 0.72           |
# Payoff Ratio                   | 1.00           | 0.82           | 0.47           | 0.80           |
# Tail Ratio                     | 1.02           | 0.89           | 0.01           | 0.85           |
#
# --- TRADING ---
# Number of Trades               | 0              | 286            | 227            | 184            |
# Win Rate                       | 49.16%         | 46.74%         | 32.92%         | 47.33%         |
# Market Exposure                | 99.92%         | 68.21%         | 15.55%         | 47.95%         |
# Avg Win (bps)                  | 2.41           | 2.59           | 1.73           | 2.46           |
# Avg Loss (bps)                 | -2.40          | -3.15          | -3.66          | -3.08          |
#
# --- DISTRIBUTION ---
# Skewness                       | -0.14          | -6.48          | -9.51          | -7.39          |
# Kurtosis                       | 8.24           | 103.78         | 167.73         | 140.49         |
# =====================================================================================
#
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202408_performance.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202408_positions_and_regimes.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202408_markov_dynamics.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202408_cost_impact.pdf
# ==============================  202409  ==============================
#
# =====================================================================================
#                            QUANTITATIVE STRATEGY TEARSHEET
# =====================================================================================
# Metric                         | BuyHold        | Baseline       | AR             | MS_AR          |
# ----------------------------------------------------------------------------------------------------
#
# --- RETURN ---
# Total Return (bps)             | -57.00         | -2202.35       | -2074.39       | -1531.94       |
# Annual Return (bps)            | -832.71        | -32176.38      | -30306.82      | -22381.68      |
# Best Month (bps)               | -57.00         | -2202.35       | -2074.39       | -1531.94       |
# Worst Month (bps)              | -57.00         | -2202.35       | -2074.39       | -1531.94       |
# Positive Months %              | 0.00%          | 0.00%          | 0.00%          | 0.00%          |
#
# --- RISK ---
# Annual Volatility (bps)        | 1108.08        | 1060.92        | 503.96         | 872.42         |
# Max Drawdown (bps)             | -250.15        | -2204.42       | -2074.39       | -1534.01       |
# Max DD Duration (bars)         | 6780           | 8387           | 8373           | 8373           |
# Ulcer Index                    | 128.23         | 1249.65        | 1120.20        | 892.98         |
# Value at Risk 95% (bps)        | -5.05          | -5.45          | -2.66          | -4.07          |
# CVaR 95% (bps)                 | -8.01          | -8.54          | -5.27          | -7.37          |
#
# --- RISK-ADJUSTED ---
# Sharpe Ratio                   | -0.75          | -30.33         | -60.14         | -25.65         |
# Sortino Ratio                  | -0.93          | -30.22         | -28.36         | -20.92         |
# Calmar Ratio                   | 3.33           | 14.60          | 14.61          | 14.59          |
# Profit Factor                  | 0.99           | 0.72           | 0.21           | 0.71           |
# Payoff Ratio                   | 0.98           | 0.81           | 0.39           | 0.80           |
# Tail Ratio                     | 1.01           | 0.75           | 0.05           | 0.71           |
#
# --- TRADING ---
# Number of Trades               | 0              | 320            | 243            | 186            |
# Win Rate                       | 50.32%         | 47.05%         | 34.63%         | 47.09%         |
# Market Exposure                | 99.86%         | 69.38%         | 16.74%         | 49.73%         |
# Avg Win (bps)                  | 1.91           | 2.03           | 1.12           | 1.92           |
# Avg Loss (bps)                 | -1.95          | -2.52          | -2.85          | -2.40          |
#
# --- DISTRIBUTION ---
# Skewness                       | -0.13          | -0.72          | -5.32          | -1.41          |
# Kurtosis                       | 9.09           | 12.00          | 61.36          | 20.29          |
# =====================================================================================
#
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202409_performance.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202409_positions_and_regimes.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202409_markov_dynamics.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202409_cost_impact.pdf
# ==============================  202508  ==============================
#
# =====================================================================================
#                            QUANTITATIVE STRATEGY TEARSHEET
# =====================================================================================
# Metric                         | BuyHold        | Baseline       | AR             | MS_AR          |
# ----------------------------------------------------------------------------------------------------
#
# --- RETURN ---
# Total Return (bps)             | 110.13         | -664.87        | -255.47        | -349.36        |
# Annual Return (bps)            | 1748.84        | -10558.49      | -4056.95       | -5548.03       |
# Best Month (bps)               | 110.13         | -664.87        | -255.47        | -349.36        |
# Worst Month (bps)              | 110.13         | -664.87        | -255.47        | -349.36        |
# Positive Months %              | 100.00%        | 0.00%          | 0.00%          | 0.00%          |
#
# --- RISK ---
# Annual Volatility (bps)        | 825.37         | 742.86         | 227.14         | 538.12         |
# Max Drawdown (bps)             | -183.18        | -674.49        | -255.47        | -378.22        |
# Max DD Duration (bars)         | 942            | 2394           | 2300           | 2368           |
# Ulcer Index                    | 78.27          | 369.23         | 161.64         | 189.14         |
# Value at Risk 95% (bps)        | -6.57          | -6.18          | 0.00           | -4.77          |
# CVaR 95% (bps)                 | -9.74          | -9.93          | -0.14          | -7.77          |
#
# --- RISK-ADJUSTED ---
# Sharpe Ratio                   | 2.12           | -14.21         | -17.86         | -10.31         |
# Sortino Ratio                  | 2.93           | -15.10         | -5.13          | -8.35          |
# Calmar Ratio                   | 9.55           | 15.65          | 15.88          | 14.67          |
# Profit Factor                  | 1.03           | 0.77           | 0.26           | 0.78           |
# Payoff Ratio                   | 1.00           | 0.90           | 0.69           | 0.91           |
# Tail Ratio                     | 1.04           | 0.84           | NaN            | 0.74           |
#
# --- TRADING ---
# Number of Trades               | 0              | 96             | 29             | 44             |
# Win Rate                       | 50.69%         | 46.00%         | 27.50%         | 46.16%         |
# Market Exposure                | 100.00%        | 65.59%         | 4.89%          | 33.43%         |
# Avg Win (bps)                  | 2.84           | 3.00           | 2.74           | 3.22           |
# Avg Loss (bps)                 | -2.83          | -3.32          | -3.98          | -3.55          |
#
# --- DISTRIBUTION ---
# Skewness                       | 0.11           | -0.55          | -10.04         | -0.55          |
# Kurtosis                       | 4.83           | 11.59          | 241.82         | 15.15          |
# =====================================================================================
#
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202508_performance.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202508_positions_and_regimes.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202508_markov_dynamics.pdf
# Saved plot PDF: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_202508_cost_impact.pdf

# %%
m.sweep('202408')
# Out:
# built 9088 rows
# Running Engine | train_days=3 | coint_window=150 | z_window=50 | k_regimes=2 | winsor=4.0σ | scale=x10000
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# === Sensitivity sweep, 202408, EURNOK_EURSEK ===
#  z_quiet  z_volatile  danger_threshold  Baseline_Sharpe  AR_Sharpe  MS_AR_Sharpe  MS_AR_Trades  MS_AR_vs_AR  MS_AR_vs_Baseline
#      1.0         2.0              0.15           -51.43     -10.22        -40.39           246       -30.16              11.05
#      1.0         2.0              0.30           -51.43    -108.43        -40.39           246        68.05              11.05
#      1.0         2.0              0.50           -51.43    -106.76        -40.39           246        66.38              11.05
#      1.0         2.5              0.15           -51.43     -10.22        -39.67           215       -29.44              11.77
#      1.0         2.5              0.30           -51.43    -108.43        -39.67           215        68.76              11.77
#      1.0         2.5              0.50           -51.43    -106.76        -39.67           215        67.10              11.77
#      1.0         3.5              0.15           -51.43     -10.22        -36.87           139       -26.65              14.56
#      1.0         3.5              0.30           -51.43    -108.43        -36.87           139        71.56              14.56
#      1.0         3.5              0.50           -51.43    -106.76        -36.87           139        69.89              14.56
#      1.3         2.0              0.15           -43.87     -10.22        -38.27           230       -28.04               5.60
#      1.3         2.0              0.30           -43.87     -87.82        -38.27           230        49.55               5.60
#      1.3         2.0              0.50           -43.87     -88.56        -38.27           230        50.29               5.60
#      1.3         2.5              0.15           -43.87     -10.22        -37.44           183       -27.21               6.43
#      1.3         2.5              0.30           -43.87     -87.82        -37.44           183        50.38               6.43
#      1.3         2.5              0.50           -43.87     -88.56        -37.44           183        51.12               6.43
#      1.3         3.5              0.15           -43.87     -10.22        -31.83           115       -21.61              12.03
#      1.3         3.5              0.30           -43.87     -87.82        -31.83           115        55.98              12.03
#      1.3         3.5              0.50           -43.87     -88.56        -31.83           115        56.72              12.03
#      1.6         2.0              0.15           -38.59       0.00        -36.98           209       -36.98               1.60
#      1.6         2.0              0.30           -38.59     -70.77        -36.98           209        33.78               1.60
#      1.6         2.0              0.50           -38.59     -75.57        -36.98           209        38.58               1.60
#      1.6         2.5              0.15           -38.59       0.00        -34.69           163       -34.69               3.90
#      1.6         2.5              0.30           -38.59     -70.77        -34.69           163        36.08               3.90
#      1.6         2.5              0.50           -38.59     -75.57        -34.69           163        40.88               3.90
#      1.6         3.5              0.15           -38.59       0.00        -29.50            83       -29.50               9.08
#      1.6         3.5              0.30           -38.59     -70.77        -29.50            83        41.26               9.08
#      1.6         3.5              0.50           -38.59     -75.57        -29.50            83        46.06               9.08
#
# MS_AR > AR       across grid: 18/27
# MS_AR > Baseline across grid: 27/27
# Saved CSV: /content/drive/MyDrive/GITHUB-COPILOT/stk-mat2011/plots/EURNOK_EURSEK/EURNOK_EURSEK_sweep_202408.csv
#     z_quiet  z_volatile  danger_threshold  Baseline_Sharpe   AR_Sharpe  \
# 0       1.0         2.0              0.15       -51.434520  -10.224666
# 1       1.0         2.0              0.30       -51.434520 -108.433313
# 2       1.0         2.0              0.50       -51.434520 -106.764654
# 3       1.0         2.5              0.15       -51.434520  -10.224666
# 4       1.0         2.5              0.30       -51.434520 -108.433313
# 5       1.0         2.5              0.50       -51.434520 -106.764654
# 6       1.0         3.5              0.15       -51.434520  -10.224666
# 7       1.0         3.5              0.30       -51.434520 -108.433313
# 8       1.0         3.5              0.50       -51.434520 -106.764654
# 9       1.3         2.0              0.15       -43.869232  -10.224666
# 10      1.3         2.0              0.30       -43.869232  -87.816314
# 11      1.3         2.0              0.50       -43.869232  -88.557117
# 12      1.3         2.5              0.15       -43.869232  -10.224666
# 13      1.3         2.5              0.30       -43.869232  -87.816314
# 14      1.3         2.5              0.50       -43.869232  -88.557117
# 15      1.3         3.5              0.15       -43.869232  -10.224666
# 16      1.3         3.5              0.30       -43.869232  -87.816314
# 17      1.3         3.5              0.50       -43.869232  -88.557117
# 18      1.6         2.0              0.15       -38.587182    0.000000
# 19      1.6         2.0              0.30       -38.587182  -70.765342
# 20      1.6         2.0              0.50       -38.587182  -75.566244
# 21      1.6         2.5              0.15       -38.587182    0.000000
# 22      1.6         2.5              0.30       -38.587182  -70.765342
# 23      1.6         2.5              0.50       -38.587182  -75.566244
# 24      1.6         3.5              0.15       -38.587182    0.000000
# 25      1.6         3.5              0.30       -38.587182  -70.765342
# 26      1.6         3.5              0.50       -38.587182  -75.566244
#
#     MS_AR_Sharpe  MS_AR_Trades  MS_AR_vs_AR  MS_AR_vs_Baseline
# 0     -40.385729           246   -30.161063          11.048791
# 1     -40.385729           246    68.047584          11.048791
# 2     -40.385729           246    66.378925          11.048791
# 3     -39.668469           215   -29.443804          11.766050
# 4     -39.668469           215    68.764843          11.766050
# 5     -39.668469           215    67.096184          11.766050
# 6     -36.873456           139   -26.648791          14.561063
# 7     -36.873456           139    71.559857          14.561063
# 8     -36.873456           139    69.891198          14.561063
# 9     -38.266297           230   -28.041632           5.602935
# 10    -38.266297           230    49.550017           5.602935
# 11    -38.266297           230    50.290820           5.602935
# 12    -37.436670           183   -27.212004           6.432562
# 13    -37.436670           183    50.379644           6.432562
# 14    -37.436670           183    51.120448           6.432562
# 15    -31.834257           115   -21.609591          12.034976
# 16    -31.834257           115    55.982058          12.034976
# 17    -31.834257           115    56.722861          12.034976
# 18    -36.983047           209   -36.983047           1.604135
# 19    -36.983047           209    33.782295           1.604135
# 20    -36.983047           209    38.583196           1.604135
# 21    -34.689472           163   -34.689472           3.897710
# 22    -34.689472           163    36.075870           3.897710
# 23    -34.689472           163    40.876771           3.897710
# 24    -29.504728            83   -29.504728           9.082454
# 25    -29.504728            83    41.260614           9.082454
# 26    -29.504728            83    46.061516           9.082454
